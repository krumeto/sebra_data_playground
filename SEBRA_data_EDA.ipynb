# %% [markdown]
# <a href="https://colab.research.google.com/github/krumeto/sebra_data_playground/blob/main/SEBRA_data_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install dateparser
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting dateparser
#   Downloading dateparser-1.1.1-py2.py3-none-any.whl (288 kB)
#      |████████████████████████████████| 288 kB 5.1 MB/s
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from dateparser) (2022.1)
# Collecting regex!=2019.02.19,!=2021.8.27,<2022.3.15
#   Downloading regex-2022.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (749 kB)
#      |████████████████████████████████| 749 kB 53.2 MB/s
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.7/dist-packages (from dateparser) (1.5.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from dateparser) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil->dateparser) (1.15.0)
# Installing collected packages: regex, dateparser
#   Attempting uninstall: regex
#     Found existing installation: regex 2022.6.2
#     Uninstalling regex-2022.6.2:
#       Successfully uninstalled regex-2022.6.2
# Successfully installed dateparser-1.1.1 regex-2022.3.2

# %%
import pandas as pd
import numpy as np
import dateparser

import altair as alt

# %%
# Data load and preprocessing helpers

def data_load_sebra(link_to_data):
    data = pd.read_csv(link_to_data, compression = 'zip')
    data["REG_DATE"] = pd.to_datetime(data["REG_DATE"]).dt.normalize()
    data["SETTLEMENT_DATE"] = pd.to_datetime(data["SETTLEMENT_DATE"]).dt.normalize()
    return(data)

def lowercase_columns(dataf):
    dataf.columns = dataf.columns.str.lower()
    return(dataf)

def add_year(dataf):
    return(
        dataf.assign(reg_year = dataf['reg_date'].dt.year)
        )
    
def uppercase_all_object_cols(dataf):
    object_cols = dataf.select_dtypes("object").columns
    # For loop instead of apply for memory purposes
    for col in object_cols:
      dataf[col] = dataf[col].str.upper()
    return(dataf)


def pull_government_periods():
    """A function to pull periods of different governments and prepare the info in a format for left join"""

    # Data pull from wikipedia
    governments = pd.read_html("https://bg.wikipedia.org/wiki/%D0%9F%D1%80%D0%B0%D0%B2%D0%B8%D1%82%D0%B5%D0%BB%D1%81%D1%82%D0%B2%D0%B0_%D0%BD%D0%B0_%D0%91%D1%8A%D0%BB%D0%B3%D0%B0%D1%80%D0%B8%D1%8F",
                              match = "Република България"
                              )[0]

    # better column names              
    governments.columns = ["gov_nr", "government_alias", "government_pm", "government_start_dt", "government_end_dt", "n_days", "party/coalition"]

    # Get only post-communist goverments
    post_com_index = governments.loc[lambda d: d["gov_nr"] == "Република България (от 1990 г.)"].index
    governments = governments.iloc[lambda d: d.index > post_com_index[0]]

    # Convert dates using dateparser
    governments.government_start_dt = governments.government_start_dt.apply(dateparser.parse)

    # Weird if-else, as the last cell of the wikipedia article is usually empty, but occasionally - not
    if sum(governments.government_end_dt.isna()) > 0:
      governments.government_end_dt.iloc[:-1] = governments.government_end_dt.iloc[:-1].apply(dateparser.parse)
    else:
      governments.government_end_dt = governments.government_end_dt.apply(dateparser.parse)


    # extra cautious with dates, as we will be joining on them later
    governments.government_start_dt = pd.to_datetime(governments.government_start_dt).dt.normalize()
    governments.government_end_dt = pd.to_datetime(governments.government_end_dt).dt.normalize()


    # Get data in a long format
    # Potentially there is a much cleaner way, but data is small and this works
    long_gov_df = pd.DataFrame(columns = ["date", "government_alias", "government_pm", 'party/coalition'])

    # Iter over all rows
    for ix, row in governments.iterrows():
      interim_df = pd.DataFrame(columns = ["date", 'government_alias', 'government_pm', 'party/coalition'])
      # create a date_range starting from the day after a government starts until the day it ends
      try:
        date_period = pd.date_range(start = row["government_start_dt"] + pd.Timedelta(days=1), end = row["government_end_dt"])
      # except for the NA for the latest government
      except ValueError:
        date_period = pd.date_range(start = row["government_start_dt"] + pd.Timedelta(days=1), end = pd.Timestamp.today())
      interim_df["date"] = date_period
      interim_df["government_alias"] = row["government_alias"]
      interim_df["government_pm"] = row["government_pm"]
      interim_df['party/coalition'] = row['party/coalition']
      long_gov_df = pd.concat([long_gov_df, interim_df])

    long_gov_df["date"] = pd.to_datetime(long_gov_df["date"]).dt.normalize()
    return(long_gov_df)


def pull_bank_names_per_bic():
    """A function to pull bank names for a given bic"""

    bics_raw = pd.read_html("https://www.bnb.bg/RegistersAndServices/RSBAEAndBIC/index.htm")

    # clean the raw output
    bics = pd.DataFrame()

    for dataf in bics_raw:
      if dataf.shape[1] == 3 and dataf.shape[0] > 0:
        bics = pd.concat([bics, dataf])

    # keep the bics only
    bics = bics.dropna().iloc[:, [0,2]].reset_index(drop=True)
    bics.columns = ["bank_name", "bic"]

    # Expired and additional bics
    additional_banks_list = [('Българска народна банка', 'BNBGBGSF'),
    ('Българска народна банка', 'BNBGBGSD'),
    ('СИБАНК', 'BUIBBGSF'),
    ('УниКредит Булбанк АД', 'BFTBBGSF'),
    ('Сосиете Женерал Експрес Банк', 'TTBBBG22'),
    ('Unknown bank', 'ACBPGS2P'),
    ('МКБ Юнионбанк АД', 'CBUNBGSF'),
    ('ДЗИ Банк АД', 'REXIBGSF'),
    ('Корпоративна търговска банка АД', 'KORPBGSF'),
    ('Пиреус Банк България АД', 'PIRBBGSF'),
    ('ТИ БИ АЙ БАНК ЕАД', 'WEBKBGSF'),
    ('Алфа банк - клон България', 'CRBABGSF'),
    ('Креди Агрикол България', 'BINVBGSF'),
    ('SG Експресбанк AD', 'TTBB22'),
    ('ISBANK AG', 'ISBKBGSF'),
    ('Ейч Ви Би Банк БиохимАД', 'BACXBGSF')
    ]


    additional_banks_df = pd.DataFrame(additional_banks_list, columns = ["bank_name", "bic"])

    bics = pd.concat([bics, additional_banks_df]).reset_index(drop = True)
    bics = bics.loc[lambda d: d['bic'].str.len() <= 8].reset_index(drop = True)

    return(bics)

def get_a_report_per_iban(dataf, iban):
    """Get a report per IBAN"""
    all_rows = dataf.loc[lambda d: d["client_receiver_acc"] == iban]
    n_hashes = (all_rows["client_name_hash"].unique())
    n_client_receiver_name = (all_rows["client_receiver_name"].unique())
    flows = (all_rows.
             groupby(["primary_organization", "reg_year"])['amount'].
             agg(["sum", 'count']).
             sort_values('reg_year'))
    
    return([all_rows, n_hashes, n_client_receiver_name, flows])


def plot_organization_timeseries(dataf, groupby_col = 'primary_organization', time_col = 'settlement_date', interactive = True, custom_title = False):
    """A plotting function after a groupby+reset_index()"""
    selection = alt.selection_multi(fields=[groupby_col], bind='legend')

    final_chart = alt.Chart(dataf).mark_line(point=alt.OverlayMarkDef()).encode(
        x= time_col,
        y='amount',
        color=alt.Color(groupby_col, scale=alt.Scale(scheme='tableau20')),
        strokeDash=groupby_col,
        tooltip = [groupby_col, time_col, 'amount'],
        opacity=alt.condition(selection, alt.value(1), alt.value(0.2))
    ).configure_legend(
        labelLimit= 0
    ).add_selection(
        selection
    ).properties(
        width=800,
        height=300,
        title = custom_title if custom_title else f"{groupby_col} over time" 
    )

    if interactive:
       final_chart = final_chart.interactive()

    return(final_chart)

# %% [markdown]
# ## Data pull
#
# The SEBRA data is stored on the Open Data Egov portal - https://data.egov.bg/organisation/datasets/resourceView/ba444b96-6ec3-4be7-8981-92bc33d1a94b
#
# Other SEBRA related datasets are available as well - for example, this one by the Ministry of Internal Affairs - https://data.egov.bg/data/view/44b1ae19-52cb-4fc1-ad66-274755652152 . I have not explored those yet.

# %%
link_to_data = "https://data.egov.bg/resource/download/zip/ba444b96-6ec3-4be7-8981-92bc33d1a94b"

data = (data_load_sebra(link_to_data).
        # Lowercase columns
        pipe(lowercase_columns).
        # Add year as a separate column
        pipe(add_year).
        # Add columns for government during the period
        # joining on settlement date gets more results than on reg_date
        merge(pull_government_periods(), 
              how ='left',
              left_on ='settlement_date',
              right_on = 'date').
        drop(columns = ['date']).
        # Add bank names
        merge(pull_bank_names_per_bic(),
              how = "left",
              left_on = "client_receiver_bic",
              right_on = "bic").
        drop(columns = ['bic']).
        pipe(uppercase_all_object_cols))
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
data.info(show_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3586569 entries, 0 to 3586568
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   settlement_date       3586569 non-null  datetime64[ns]
#  1   client_receiver_name  3586569 non-null  object
#  2   client_receiver_acc   3586569 non-null  object
#  3   client_receiver_bic   3586569 non-null  object
#  4   fin_code              3586569 non-null  int64
#  5   amount                3586569 non-null  float64
#  6   currency              3586569 non-null  object
#  7   reason1               3459986 non-null  object
#  8   reason2               2626159 non-null  object
#  9   reg_date              3586569 non-null  datetime64[ns]
#  10  reg_no                3586569 non-null  object
#  11  sebra_pay_code        3586569 non-null  int64
#  12  organization          3586569 non-null  object
#  13  primary_organization  3586569 non-null  object
#  14  primary_org_code      3586569 non-null  int64
#  15  client_name_hash      3586569 non-null  object
#  16  reg_year              3586569 non-null  int64
#  17  government_alias      3571460 non-null  object
#  18  government_pm         3571460 non-null  object
#  19  party/coalition       3571460 non-null  object
#  20  bank_name             3586569 non-null  object
# dtypes: datetime64[ns](2), float64(1), int64(4), object(14)
# memory usage: 602.0+ MB

# %%
data.sample(10)
# Out:
#         settlement_date        client_receiver_name     client_receiver_acc  \
# 2595544      2019-04-25    ЕТ НИВА-60-ТОДОР СТОЯНОВ  BG61STSA93000010984921
# 69039        2006-12-19            ОЗИРИС 2002 ЕООД  BG20BFTB76301075747584
# 2585288      2019-04-23     СТОЛИЧНА ОБЩИНСКА БАНКА  BG32SOMB91301000913002
# 973619       2012-10-05  БЪЛГ. ПАРАОЛИМП. АСОЦИАЦИЯ  BG64STSA93000000024158
# 2693620      2019-09-27            ДЗЗД ОГОСТА 2017  BG82UBBS88881000935907
# 2152090      2017-03-08       ТД НА НАП ОФ.С ИЯ СДО  BG43BUIB98883322944000
# 1051969      2012-10-25      БЪЛГАРСКИ ПОЩИ ПЛОВДИВ  BG96BUIB78363302026701
# 2929183      2020-07-23  ЕООД Д-Р ХРИСТО КИРИЛОВ ИП  BG12UNCR70001519991115
# 995092       2012-06-28        ЕВРОПА - В.И.П.  ООД  BG04FINV91501000175687
# 2064448      2017-03-24          ИНСТИТУТ ЗА ГОРАТА  BG45UNCR96603107050229
#
#         client_receiver_bic    fin_code     amount currency  \
# 2595544            STSABGSF  1220093218   94114.80      BGN
# 69039              BFTBBGSF   161250001   29481.92      BGN
# 2585288            SOMBBGSF   550090009   43753.83      BGN
# 973619             STSABGSF   250000004   96616.00      BGN
# 2693620            UBBSBGSF  4444330017  105672.76      BGN
# 2152090            BUIBBGSF   210050006   10621.78      BGN
# 1051969            BUIBBGSF   550090164   11652.62      BGN
# 2929183            UNCRBGSF   560220007    5800.52      BGN
# 995092             FINVBGSF   560160000    5888.79      BGN
# 2064448            UNCRBGSF  8900290000   15449.80      BGN
#
#                                      reason1                      reason2  \
# 2595544                          ЗЕЛЕНИ 2018                          NaN
# 69039                                    NaN                        10 16
# 2585288                         19SOMBPD.031   0419 04199121082521 220419
# 973619                            ДОГОВОР ОП   0512 05129РД 09 196 080512
# 2693620                             КАП.Р ДИ  0919 091990000000010 120919
# 2152090            ЗАПОР НА ОРС  ИД170286248   0817 081791000000414310717
# 1051969                     Z1523101215D.TXT                    1012 1012
# 2929183           Д.N 221654/2020     390101  0620 0620900000004161407209
# 995092   Д.N 162276/2012       СИМП0512 0512            90000000147010612
# 2064448           ЗАХР.03/17 ПР.TUNES IN URB          0317 03179000662192
#
#           reg_date  ... sebra_pay_code  \
# 2595544 2019-04-24  ...             89
# 69039   2006-12-18  ...             10
# 2585288 2019-04-22  ...             40
# 973619  2012-09-05  ...             30
# 2693620 2019-09-26  ...             50
# 2152090 2017-02-08  ...             50
# 1051969 2012-10-24  ...             40
# 2929183 2020-07-22  ...             40
# 995092  2012-06-27  ...             40
# 2064448 2017-03-23  ...             88
#
#                                               organization  \
# 2595544                       РАЗПЛ А-ИЯ-ДИРЕКТНИ-ПЛАЩАНИЯ
# 69039                                       ЦСМП-ТЪРГОВИЩЕ
# 2585288                                ДОО-ПЕНСИИ - НОИ-ЦУ
# 973619   МИНИСТЕРСТВО НА ФИЗИЧЕСКОТО ВЪЗПИТАНИЕ И СПОРТ...
# 2693620                         БОТЕВГРАД - КАПИТАЛОВА С-Я
# 2152090                  АГЕНЦИЯ "ПЪТНА ИНФРАСТРУКТУРА"-ЦУ
# 1051969                          ДОО-ПЕНСИИ - РУСО-ПЛОВДИВ
# 2929183                                    РЗОК-СОФИЯ-ГРАД
# 995092                                        РЗОК-ПЛОВДИВ
# 2064448                              28-ИНСТИТУТ ЗА ГОРАТА
#
#                                     primary_organization primary_org_code  \
# 2595544               ДФ ЗЕМЕДЕЛИЕ-РАЗПЛАЩАТЕЛНА АГЕНЦИЯ              122
# 69039                   МИНИСТЕРСТВО НА ЗДРАВЕОПАЗВАНЕТО               16
# 2585288                                        НОИ - ДОО               55
# 973619   МИНИСТЕРСТВО НА ФИЗИЧЕСКОТО ВЪЗПИТАНИЕ И СПОРТА               25
# 2693620                          ЦБ - СУБСИДИИ ЗА ОБЩИНИ              444
# 2152090              МИНИСТЕРСТВО НА РЕГИОНАЛНОТО РАЗВИТ               21
# 1051969                                        НОИ - ДОО               55
# 2929183                                             НЗОК               56
# 995092                                              НЗОК               56
# 2064448                    БЪЛГАРСКА АКАДЕМИЯ НА НАУКИТЕ              890
#
#                                           client_name_hash reg_year  \
# 2595544  BCFBFD42CFECBF455073BB6AEDFFA62A6DD5AC842D987B...     2019
# 69039    2BBA42F71D5180198928F4EFCBFBB9A8DCF32F75608BB4...     2006
# 2585288  B5C972015FB8DCCA452DD281E96E3ABA37E09735E6A927...     2019
# 973619   6877A39621D652CE5ADE2333C4F944464EB99E77589009...     2012
# 2693620  9AB1C955ECA75604F8F1FAAA5EC8FDAD9BE540D680ACEF...     2019
# 2152090  17439F6670EBE33050D3B4790FD4B9A31ECD33323CC2EF...     2017
# 1051969  33A0BA33FFCE5413A580DBA09FA5DF76C8F9FCCA1C05EE...     2012
# 2929183  4001E4A6792A71FF25B27FD73EFCCF23B133B709E61CC8...     2020
# 995092   6E15DCE08389515865877529FD84523C39CA7FCB660020...     2012
# 2064448  B0C92593E2A66C0AD77F187435205EED44F3BDFAD5C1D5...     2017
#
#          government_alias               government_pm  \
# 2595544         БОРИСОВ 3    БОЙКО БОРИСОВ(РОД. 1959)
# 69039            СТАНИШЕВ  СЕРГЕЙ СТАНИШЕВ(РОД. 1966)
# 2585288         БОРИСОВ 3    БОЙКО БОРИСОВ(РОД. 1959)
# 973619          БОРИСОВ 1    БОЙКО БОРИСОВ(РОД. 1959)
# 2693620         БОРИСОВ 3    БОЙКО БОРИСОВ(РОД. 1959)
# 2152090         ГЕРДЖИКОВ  ОГНЯН ГЕРДЖИКОВ(РОД. 1946)
# 1051969         БОРИСОВ 1    БОЙКО БОРИСОВ(РОД. 1959)
# 2929183         БОРИСОВ 3    БОЙКО БОРИСОВ(РОД. 1959)
# 995092          БОРИСОВ 1    БОЙКО БОРИСОВ(РОД. 1959)
# 2064448         ГЕРДЖИКОВ  ОГНЯН ГЕРДЖИКОВ(РОД. 1946)
#
#                   party/coalition                     bank_name
# 2595544  ГЕРБ, ОБЕДИНЕНИ ПАТРИОТИ                  БАНКА ДСК АД
# 69039              БСП, НДСВ, ДПС          УНИКРЕДИТ БУЛБАНК АД
# 2585288  ГЕРБ, ОБЕДИНЕНИ ПАТРИОТИ             ОБЩИНСКА БАНКА АД
# 973619                    ГЕРБ[3]                  БАНКА ДСК АД
# 2693620  ГЕРБ, ОБЕДИНЕНИ ПАТРИОТИ  ОБЕДИНЕНА БЪЛГАРСКА БАНКА АД
# 2152090      СЛУЖЕБЕН; НЕЗАВИСИМИ                        СИБАНК
# 1051969                   ГЕРБ[3]                        СИБАНК
# 2929183  ГЕРБ, ОБЕДИНЕНИ ПАТРИОТИ          УНИКРЕДИТ БУЛБАНК АД
# 995092                    ГЕРБ[3]  ПЪРВА ИНВЕСТИЦИОННА БАНКА АД
# 2064448      СЛУЖЕБЕН; НЕЗАВИСИМИ          УНИКРЕДИТ БУЛБАНК АД
#
# [10 rows x 21 columns]

# %% [markdown]
# ### Brief EDA

# %% [markdown]
# #### Settlement and reg_date Dates differ mostly by a day, but also by about a month, two or three months

# %%
settlement_date_minus_reg_date = (data.settlement_date - data.reg_date).dt.days

print("Settlement date minus reg_date:\n\n", 
      (settlement_date_minus_reg_date.
      describe(percentiles = [.10, .25, .5, .75, .90]).
      round(2)), 
      sep = "")


print("Most frequent delta between settlement date and reg_date:\n\n", 
      (settlement_date_minus_reg_date.value_counts().nlargest(20)), 
      sep = "")

((settlement_date_minus_reg_date.
      plot.hist(bins =30, title = "Settlement date minus Reg date in days")))
# Out:
# Settlement date minus reg_date:
#
# count    3586569.00
# mean           5.11
# std           58.28
# min         -334.00
# 10%            1.00
# 25%            1.00
# 50%            1.00
# 75%           30.00
# 90%           31.00
# max          359.00
# dtype: float64
# Most frequent delta between settlement date and reg_date:
#
# 1      1601977
# 31      318390
# 3       280297
# 30      270266
# 2       170394
# 0        99359
# 4        93987
# 92       92954
# 28       41288
# 61       39727
# 5        37595
# 91       31847
# 6        25507
# 122      19310
# 29       17279
# 7        15093
# 90       14776
# 123      11436
# 153       9693
# 89        9313
# dtype: int64

# %%
# Only transfers in BGN
## TODO think of some inflation adjustments
data.currency.unique()
# Out:
# array(['BGN'], dtype=object)

# %% [markdown]
# ### Biggest overall flows (not very telling)
#
# Better to aggregate by primary_org_code and then get the main name. See different names for НОИ.

# %%
overall_flows = data.groupby(["primary_organization", "primary_org_code", "client_receiver_name"], as_index = False)['amount'].agg(["sum", 'count']).reset_index()

overall_flows.nlargest(20, columns = ['sum']).style.format({"sum": "{:,.0f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_a05c9_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >primary_organization</th>
#       <th class="col_heading level0 col1" >primary_org_code</th>
#       <th class="col_heading level0 col2" >client_receiver_name</th>
#       <th class="col_heading level0 col3" >sum</th>
#       <th class="col_heading level0 col4" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a05c9_level0_row0" class="row_heading level0 row0" >268461</th>
#       <td id="T_a05c9_row0_col0" class="data row0 col0" >НОИ - ДОО</td>
#       <td id="T_a05c9_row0_col1" class="data row0 col1" >55</td>
#       <td id="T_a05c9_row0_col2" class="data row0 col2" >БАНКА ДСК АД   ЦУ ГР.СОФИЯ</td>
#       <td id="T_a05c9_row0_col3" class="data row0 col3" >23,668,491,106</td>
#       <td id="T_a05c9_row0_col4" class="data row0 col4" >1559</td>
#     </tr>
#     <tr>
#       <th id="T_a05c9_level0_row1" class="row_heading level0 row1" >271544</th>
#       <td id="T_a05c9_row1_col0" class="data row1 col0" >НОИ - ДОО</td>
#       <td id="T_a05c9_row1_col1" class="data row1 col1" >55</td>
#       <td id="T_a05c9_row1_col2" class="data row1 col2" >ОББ АД  КЛ. ЦЕНТРАЛЕН</td>
#       <td id="T_a05c9_row1_col3" class="data row1 col3" >6,501,729,692</td>
#       <td id="T_a05c9_row1_col4" class="data row1 col4" >1408</td>
#     </tr>
#     <tr>
#       <th id="T_a05c9_level0_row2" class="row_heading level0 row2" >327308</th>
#       <td id="T_a05c9_row2_col0" class="data row2 col0" >ЦБ - СУБСИДИИ ЗА ОБЩИНИ</td>
#       <td id="T_a05c9_row2_col1" class="data row2 col1" >444</td>
#       <td id="T_a05c9_row2_col2" class="data row2 col2" >СТОЛИЧНА ОБЩИНА</td>
#       <td id="T_a05c9_row2_col3" class="data row2 col3" >6,001,380,848</td>
#       <td id="T_a05c9_row2_col4" class="data row2 col4" >826</td>
#     </tr>
#     <tr>
#       <th id="T_a05c9_level0_row3" class="row_heading level0 row3" >159856</th>
#       <td id="T_a05c9_row3_col0" class="data row3 col0" >МИНИСТЕРСТВО НА РЕГИОНАЛНОТО РАЗВИТ</td>
#       <td id="T_a05c9_row3_col1" class="data row3 col1" >21</td>
#       <td id="T_a05c9_row3_col2" class="data row3 col2" >МРРБ</td>
#       <td id="T_a05c9_row3_col3" class="data row3 col3" >5,191,383,748</td>
#       <td id="T_a05c9_row3_col4" class="data row3 col4" >1697</td>
#     </tr>
#     <tr>
#       <th id="T_a05c9_level0_row4" class="row_heading level0 row4" >301575</th>
#       <td id="T_a05c9_row4_col0" class="data row4 col0" >ПРЕДПРИЯТИЕ ЗА УПРАВЛЕНИЕ НА ДЕЙНОСТИТЕ ПО ОПАЗВАНЕ НА ОКОЛНАТА СРЕДА</td>
#       <td id="T_a05c9_row4_col1" class="data row4 col1" >119</td>
#       <td id="T_a05c9_row4_col2" class="data row4 col2" >ФОНД "СЕЛС"</td>
#       <td id="T_a05c9_row4_col3" class="data row4 col3" >5,156,011,246</td>
#       <td id="T_a05c9_row4_col4" class="data row4 col4" >76</td>
#     </tr>
#     <tr>
#       <th id="T_a05c9_level0_row5" class="row_heading level0 row5" >311600</th>
#       <td id="T_a05c9_row5_col0" class="data row5 col0" >ФОНД "СИГУРНОСТ НА ЕЛЕКТРОЕНЕРГИЙНАТА СИСТЕМА"</td>
#       <td id="T_a05c9_row5_col1" class="data row5 col1" >124</td>
#       <td id="T_a05c9_row5_col2" class="data row5 col2" >НЕК ЕАД</td>
#       <td id="T_a05c9_row5_col3" class="data row5 col3" >4,995,101,853</td>
#       <td id="T_a05c9_row5_col4" class="data row5 col4" >81</td>
#     </tr>
#     <tr>
#       <th id="T_a05c9_level0_row6" class="row_heading level0 row6" >272269</th>
#       <td id="T_a05c9_row6_col0" class="data row6 col0" >НОИ - ДОО</td>
#       <td id="T_a05c9_row6_col1" class="data row6 col1" >55</td>
#       <td id="T_a05c9_row6_col2" class="data row6 col2" >ПЪРВА ИНВЕСТИЦИОННА БАНКА</td>
#       <td id="T_a05c9_row6_col3" class="data row6 col3" >4,869,167,924</td>
#       <td id="T_a05c9_row6_col4" class="data row6 col4" >2640</td>
#     </tr>
#     <tr>
#       <th id="T_a05c9_level0_row7" class="row_heading level0 row7" >273653</th>
#       <td id="T_a05c9_row7_col0" class="data row7 col0" >НОИ - ДОО</td>
#       <td id="T_a05c9_row7_col1" class="data row7 col1" >55</td>
#       <td id="T_a05c9_row7_col2" class="data row7 col2" >ТП СПС</td>
#       <td id="T_a05c9_row7_col3" class="data row7 col3" >4,797,700,358</td>
#       <td id="T_a05c9_row7_col4" class="data row7 col4" >3153</td>
#     </tr>
#     <tr>
#       <th id="T_a05c9_level0_row8" class="row_heading level0 row8" >274439</th>
#       <td id="T_a05c9_row8_col0" class="data row8 col0" >НОИ - ДОО</td>
#       <td id="T_a05c9_row8_col1" class="data row8 col1" >55</td>
#       <td id="T_a05c9_row8_col2" class="data row8 col2" >ЮРОБАНК БЪЛГАРИЯ АД</td>
#       <td id="T_a05c9_row8_col3" class="data row8 col3" >4,444,238,403</td>
#       <td id="T_a05c9_row8_col4" class="data row8 col4" >1456</td>
#     </tr>
#     <tr>
#       <th id="T_a05c9_level0_row9" class="row_heading level0 row9" >53272</th>
#       <td id="T_a05c9_row9_col0" class="data row9 col0" >ДФ ЗЕМЕДЕЛИЕ-РАЗПЛАЩАТЕЛНА АГЕНЦИЯ</td>
#       <td id="T_a05c9_row9_col1" class="data row9 col1" >122</td>
#       <td id="T_a05c9_row9_col2" class="data row9 col2" >ФИЗИЧЕСКО ЛИЦЕ</td>
#       <td id="T_a05c9_row9_col3" class="data row9 col3" >4,361,584,058</td>
#       <td id="T_a05c9_row9_col4" class="data row9 col4" >296376</td>
#     </tr>
#     <tr>
#       <th id="T_a05c9_level0_row10" class="row_heading level0 row10" >268893</th>
#       <td id="T_a05c9_row10_col0" class="data row10 col0" >НОИ - ДОО</td>
#       <td id="T_a05c9_row10_col1" class="data row10 col1" >55</td>
#       <td id="T_a05c9_row10_col2" class="data row10 col2" >БЪЛГАРСКИ ПОЩИ ПЛОВДИВ</td>
#       <td id="T_a05c9_row10_col3" class="data row10 col3" >3,927,195,205</td>
#       <td id="T_a05c9_row10_col4" class="data row10 col4" >2820</td>
#     </tr>
#     <tr>
#       <th id="T_a05c9_level0_row11" class="row_heading level0 row11" >273808</th>
#       <td id="T_a05c9_row11_col0" class="data row11 col0" >НОИ - ДОО</td>
#       <td id="T_a05c9_row11_col1" class="data row11 col1" >55</td>
#       <td id="T_a05c9_row11_col2" class="data row11 col2" >УНИКРЕДИТ БУЛБАНК    ХЕБРОС</td>
#       <td id="T_a05c9_row11_col3" class="data row11 col3" >3,587,246,876</td>
#       <td id="T_a05c9_row11_col4" class="data row11 col4" >1187</td>
#     </tr>
#     <tr>
#       <th id="T_a05c9_level0_row12" class="row_heading level0 row12" >268463</th>
#       <td id="T_a05c9_row12_col0" class="data row12 col0" >НОИ - ДОО</td>
#       <td id="T_a05c9_row12_col1" class="data row12 col1" >55</td>
#       <td id="T_a05c9_row12_col2" class="data row12 col2" >БАНКА ДСК ЕАД</td>
#       <td id="T_a05c9_row12_col3" class="data row12 col3" >3,585,191,223</td>
#       <td id="T_a05c9_row12_col4" class="data row12 col4" >1264</td>
#     </tr>
#     <tr>
#       <th id="T_a05c9_level0_row13" class="row_heading level0 row13" >275016</th>
#       <td id="T_a05c9_row13_col0" class="data row13 col0" >НОИ ? ДЪРЖАВНО ОБЩЕСТВЕНО ОСИГУРЯВА</td>
#       <td id="T_a05c9_row13_col1" class="data row13 col1" >55</td>
#       <td id="T_a05c9_row13_col2" class="data row13 col2" >БАНКА ДСК</td>
#       <td id="T_a05c9_row13_col3" class="data row13 col3" >3,531,074,376</td>
#       <td id="T_a05c9_row13_col4" class="data row13 col4" >5291</td>
#     </tr>
#     <tr>
#       <th id="T_a05c9_level0_row14" class="row_heading level0 row14" >274166</th>
#       <td id="T_a05c9_row14_col0" class="data row14 col0" >НОИ - ДОО</td>
#       <td id="T_a05c9_row14_col1" class="data row14 col1" >55</td>
#       <td id="T_a05c9_row14_col2" class="data row14 col2" >ЦЕНТРАЛНА КООП.БАНКА   ЦУ</td>
#       <td id="T_a05c9_row14_col3" class="data row14 col3" >3,309,144,026</td>
#       <td id="T_a05c9_row14_col4" class="data row14 col4" >1236</td>
#     </tr>
#     <tr>
#       <th id="T_a05c9_level0_row15" class="row_heading level0 row15" >279104</th>
#       <td id="T_a05c9_row15_col0" class="data row15 col0" >НОИ ? ДЪРЖАВНО ОБЩЕСТВЕНО ОСИГУРЯВА</td>
#       <td id="T_a05c9_row15_col1" class="data row15 col1" >55</td>
#       <td id="T_a05c9_row15_col2" class="data row15 col2" >ТП СОФИЙСКИ ПОЩЕНСКИ СЪОБЩЕНИЯ</td>
#       <td id="T_a05c9_row15_col3" class="data ro

# %% [markdown]
# Biggest flows excl. НОИ?

# %%
(overall_flows.loc[lambda d: d["primary_org_code"] != 55].
 nlargest(20, columns = ['sum']).
 style.format({"sum": "{:,.0f}"}))
# Out:
# <style type="text/css">
# </style>
# <table id="T_2424d_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >primary_organization</th>
#       <th class="col_heading level0 col1" >primary_org_code</th>
#       <th class="col_heading level0 col2" >client_receiver_name</th>
#       <th class="col_heading level0 col3" >sum</th>
#       <th class="col_heading level0 col4" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2424d_level0_row0" class="row_heading level0 row0" >327308</th>
#       <td id="T_2424d_row0_col0" class="data row0 col0" >ЦБ - СУБСИДИИ ЗА ОБЩИНИ</td>
#       <td id="T_2424d_row0_col1" class="data row0 col1" >444</td>
#       <td id="T_2424d_row0_col2" class="data row0 col2" >СТОЛИЧНА ОБЩИНА</td>
#       <td id="T_2424d_row0_col3" class="data row0 col3" >6,001,380,848</td>
#       <td id="T_2424d_row0_col4" class="data row0 col4" >826</td>
#     </tr>
#     <tr>
#       <th id="T_2424d_level0_row1" class="row_heading level0 row1" >159856</th>
#       <td id="T_2424d_row1_col0" class="data row1 col0" >МИНИСТЕРСТВО НА РЕГИОНАЛНОТО РАЗВИТ</td>
#       <td id="T_2424d_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_2424d_row1_col2" class="data row1 col2" >МРРБ</td>
#       <td id="T_2424d_row1_col3" class="data row1 col3" >5,191,383,748</td>
#       <td id="T_2424d_row1_col4" class="data row1 col4" >1697</td>
#     </tr>
#     <tr>
#       <th id="T_2424d_level0_row2" class="row_heading level0 row2" >301575</th>
#       <td id="T_2424d_row2_col0" class="data row2 col0" >ПРЕДПРИЯТИЕ ЗА УПРАВЛЕНИЕ НА ДЕЙНОСТИТЕ ПО ОПАЗВАНЕ НА ОКОЛНАТА СРЕДА</td>
#       <td id="T_2424d_row2_col1" class="data row2 col1" >119</td>
#       <td id="T_2424d_row2_col2" class="data row2 col2" >ФОНД "СЕЛС"</td>
#       <td id="T_2424d_row2_col3" class="data row2 col3" >5,156,011,246</td>
#       <td id="T_2424d_row2_col4" class="data row2 col4" >76</td>
#     </tr>
#     <tr>
#       <th id="T_2424d_level0_row3" class="row_heading level0 row3" >311600</th>
#       <td id="T_2424d_row3_col0" class="data row3 col0" >ФОНД "СИГУРНОСТ НА ЕЛЕКТРОЕНЕРГИЙНАТА СИСТЕМА"</td>
#       <td id="T_2424d_row3_col1" class="data row3 col1" >124</td>
#       <td id="T_2424d_row3_col2" class="data row3 col2" >НЕК ЕАД</td>
#       <td id="T_2424d_row3_col3" class="data row3 col3" >4,995,101,853</td>
#       <td id="T_2424d_row3_col4" class="data row3 col4" >81</td>
#     </tr>
#     <tr>
#       <th id="T_2424d_level0_row4" class="row_heading level0 row4" >53272</th>
#       <td id="T_2424d_row4_col0" class="data row4 col0" >ДФ ЗЕМЕДЕЛИЕ-РАЗПЛАЩАТЕЛНА АГЕНЦИЯ</td>
#       <td id="T_2424d_row4_col1" class="data row4 col1" >122</td>
#       <td id="T_2424d_row4_col2" class="data row4 col2" >ФИЗИЧЕСКО ЛИЦЕ</td>
#       <td id="T_2424d_row4_col3" class="data row4 col3" >4,361,584,058</td>
#       <td id="T_2424d_row4_col4" class="data row4 col4" >296376</td>
#     </tr>
#     <tr>
#       <th id="T_2424d_level0_row5" class="row_heading level0 row5" >324012</th>
#       <td id="T_2424d_row5_col0" class="data row5 col0" >ЦБ - СУБСИДИИ ЗА ОБЩИНИ</td>
#       <td id="T_2424d_row5_col1" class="data row5 col1" >444</td>
#       <td id="T_2424d_row5_col2" class="data row5 col2" >ОБЩИНА ПЛОВДИВ</td>
#       <td id="T_2424d_row5_col3" class="data row5 col3" >2,009,567,216</td>
#       <td id="T_2424d_row5_col4" class="data row5 col4" >608</td>
#     </tr>
#     <tr>
#       <th id="T_2424d_level0_row6" class="row_heading level0 row6" >323642</th>
#       <td id="T_2424d_row6_col0" class="data row6 col0" >ЦБ - СУБСИДИИ ЗА ОБЩИНИ</td>
#       <td id="T_2424d_row6_col1" class="data row6 col1" >444</td>
#       <td id="T_2424d_row6_col2" class="data row6 col2" >ОБЩИНА ВАРНА</td>
#       <td id="T_2424d_row6_col3" class="data row6 col3" >1,874,841,944</td>
#       <td id="T_2424d_row6_col4" class="data row6 col4" >633</td>
#     </tr>
#     <tr>
#       <th id="T_2424d_level0_row7" class="row_heading level0 row7" >35168</th>
#       <td id="T_2424d_row7_col0" class="data row7 col0" >ДФ "ЗЕМЕДЕЛИЕ"</td>
#       <td id="T_2424d_row7_col1" class="data row7 col1" >122</td>
#       <td id="T_2424d_row7_col2" class="data row7 col2" >ФИЗИЧЕСКО ЛИЦЕ</td>
#       <td id="T_2424d_row7_col3" class="data row7 col3" >1,764,410,206</td>
#       <td id="T_2424d_row7_col4" class="data row7 col4" >108355</td>
#     </tr>
#     <tr>
#       <th id="T_2424d_level0_row8" class="row_heading level0 row8" >312131</th>
#       <td id="T_2424d_row8_col0" class="data row8 col0" >ФОНД "СИГУРНОСТ НА ЕЛЕКТРОЕНЕРГИЙНАТА СИСТЕМА"</td>
#       <td id="T_2424d_row8_col1" class="data row8 col1" >124</td>
#       <td id="T_2424d_row8_col2" class="data row8 col2" >ФСЕЛС</td>
#       <td id="T_2424d_row8_col3" class="data row8 col3" >1,584,211,887</td>
#       <td id="T_2424d_row8_col4" class="data row8 col4" >60</td>
#     </tr>
#     <tr>
#       <th id="T_2424d_level0_row9" class="row_heading level0 row9" >156451</th>
#       <td id="T_2424d_row9_col0" class="data row9 col0" >МИНИСТЕРСТВО НА РЕГИОНАЛНОТО РАЗВИТ</td>
#       <td id="T_2424d_row9_col1" class="data row9 col1" >21</td>
#       <td id="T_2424d_row9_col2" class="data row9 col2" >АВТОМАГИСТРАЛИ ЕАД</td>
#       <td id="T_2424d_row9_col3" class="data row9 col3" >1,400,825,688</td>
#       <td id="T_2424d_row9_col4" class="data row9 col4" >516</td>
#     </tr>
#     <tr>
#       <th id="T_2424d_level0_row10" class="row_heading level0 row10" >263222</th>
#       <td id="T_2424d_row10_col0" class="data row10 col0" >НЗОК</td>
#       <td id="T_2424d_row10_col1" class="data row10 col1" >56</td>
#       <td id="T_2424d_row10_col2" class="data row10 col2" >НАЦИОН.ЗДРАВНООСИГУР.КАСА</td>
#       <td id="T_2424d_row10_col3" class="data row10 col3" >1,388,269,560</td>
#       <td id="T_2424d_row10_col4" class="data row10 col4" >1543</td>
#     </tr>
#     <tr>
#       <th id="T_2424d_level0_row11" class="row_heading level0 row11" >57447</th>
#       <td id="T_2424d_row11_col0" class="data row11 col0" >ДЪРЖАВЕН ФОНД ЗЕМЕДЕЛИЕ</td>
#       <td id="T_2424d_row11_col1" class="data row11 col1" >84</td>
#       <td id="T_2424d_row11_col2" class="data row11 col2" >ДФ ЗЕМЕДЕЛИЕ   РА</td>
#       <td id="T_2424d_row11_col3" class="data row11 col3" >1,358,600,848</td>
#       <td id="T_2424d_row11_col4" class="data row11 col4" >79</td>
#     </tr>
#     <tr>
#       <th id="T_2424d_level0_row12" class="row_heading level0 row12" >323626</th>
#       <td id="T_2424d_row12_col0" class="data row12 col0" >ЦБ - СУБСИДИИ ЗА ОБЩИНИ</td>
#       <td id="T_2424d_row12_col1" class="data row12 col1" >444</td>
#       <td id="T_2424d_row12_col2" class="data row12 col2" >ОБЩИНА БУРГАС</td>
#       <td id="T_2424d_row12_col3" class="data row12 col3" >1,290,166,430</td>
#       <td id="T_2424d_row12_col4" class="data row12 col4" >594</td>
#     </tr>
#     <tr>
#       <th id="T_2424d_level0_row13" class="row_heading level0 row13" >165064</th>
#       <td id="T_2424d_row13_col0" class="data row13 col0" >МИНИСТЕРСТВО НА ТРАНСПОРТА</td>
#       <td id="T_2424d_row13_col1" class="data row13 col1" >23</td>
#       <td id="T_2424d_row13_col2" class="data row13 col2" >МИНИСТЕРСТВО НА ТРАНСП.ИНФ.ТЕХНОЛ.</td>
#       <td id="T_2424d_row13_col3" class="data row13 col3" >1,274,563,611</td>
#       <td id="T_2424d_row13_col4" class="data row13 col4" >2156</td>
#     </tr>
#     <tr>
#       <th id="T_2424d_level0_row14" class="row_heading level0 row14" >83182</th>
#       <td id="T_2424d_row14_col0" class="data row14 col0" >МИНИСТЕРСТВО НА ЕНЕРГЕТИКАТА</td>
#       <td id="T_2424d_row14_col1" class="data row14 col1" >24</td>
#       <td id="T_2424d_row14_col2" class="data row14 col2" >МИНИСТЕРСТВО НА ЕНЕРГЕТИКАТА</td>
#       <td id="T_2424d_row14_col3" class="data row14 col3" >1,183,353,513</td>
#       <td id="T_2424d_row14_col4" class="data row14 col4" >292</td>
#     </tr>
#     <tr>
#       <th id="T_2424d_level0_row15" class="row_heading level0 row15" >18464</th>
#       <td id="T_2424d_row15_col0" class="data row15 col0" >ДА "ДЪРЖАВЕН РЕЗЕРВ И ВОЕННОВРЕМЕННИ ЗАПАСИ"</td>
#       <td id="T_2424d_row15_col1" class="data row15 col1" >53</td>
#       <td id="T_2424d_row

# %% [markdown]
# ## Top individuals per amount transferred
#
# Most of the top individual's seem to be just some organization using a personal name for a number of transfers.
#
# The `get_a_report_per_iban()` function provides a list of `pandas` objects (DataFrames and Series) that can be accessed by index, but also reviewed as is.

# %%
(data.
 loc[(data["client_receiver_name"] == "ФИЗИЧЕСКО ЛИЦЕ")].
 groupby(["client_receiver_acc", "bank_name"])['amount'].
 agg(["sum", 'count']).
 sort_values('sum', ascending = False).
 head(20).
 style.format("{:,.0f}")
 )
# Out:
# <style type="text/css">
# </style>
# <table id="T_a10e7_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >sum</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >client_receiver_acc</th>
#       <th class="index_name level1" >bank_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a10e7_level0_row0" class="row_heading level0 row0" >BG40BNBG96611000066123</th>
#       <th id="T_a10e7_level1_row0" class="row_heading level1 row0" >БЪЛГАРСКА НАРОДНА БАНКА</th>
#       <td id="T_a10e7_row0_col0" class="data row0 col0" >285,715,372</td>
#       <td id="T_a10e7_row0_col1" class="data row0 col1" >9,980</td>
#     </tr>
#     <tr>
#       <th id="T_a10e7_level0_row1" class="row_heading level0 row1" >BG95BPBI79421076516501</th>
#       <th id="T_a10e7_level1_row1" class="row_heading level1 row1" >ЮРОБАНК БЪЛГАРИЯ АД</th>
#       <td id="T_a10e7_row1_col0" class="data row1 col0" >262,899,263</td>
#       <td id="T_a10e7_row1_col1" class="data row1 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_a10e7_level0_row2" class="row_heading level0 row2" >BG52RZBB91553120008113</th>
#       <th id="T_a10e7_level1_row2" class="row_heading level1 row2" >КЕЙ БИ СИ БАНК БЪЛГАРИЯ ЕАД</th>
#       <td id="T_a10e7_row2_col0" class="data row2 col0" >57,932,168</td>
#       <td id="T_a10e7_row2_col1" class="data row2 col1" >98</td>
#     </tr>
#     <tr>
#       <th id="T_a10e7_level0_row3" class="row_heading level0 row3" >BG26RZBB91553100055002</th>
#       <th id="T_a10e7_level1_row3" class="row_heading level1 row3" >КЕЙ БИ СИ БАНК БЪЛГАРИЯ ЕАД</th>
#       <td id="T_a10e7_row3_col0" class="data row3 col0" >44,503,471</td>
#       <td id="T_a10e7_row3_col1" class="data row3 col1" >136</td>
#     </tr>
#     <tr>
#       <th id="T_a10e7_level0_row4" class="row_heading level0 row4" >BG86TTBB94001525796131</th>
#       <th id="T_a10e7_level1_row4" class="row_heading level1 row4" >СОСИЕТЕ ЖЕНЕРАЛ ЕКСПРЕС БАНК</th>
#       <td id="T_a10e7_row4_col0" class="data row4 col0" >24,315,169</td>
#       <td id="T_a10e7_row4_col1" class="data row4 col1" >255</td>
#     </tr>
#     <tr>
#       <th id="T_a10e7_level0_row5" class="row_heading level0 row5" >BG27KORP92201000000100</th>
#       <th id="T_a10e7_level1_row5" class="row_heading level1 row5" >КОРПОРАТИВНА ТЪРГОВСКА БАНКА АД</th>
#       <td id="T_a10e7_row5_col0" class="data row5 col0" >16,489,738</td>
#       <td id="T_a10e7_row5_col1" class="data row5 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_a10e7_level0_row6" class="row_heading level0 row6" >BG94BPBI79421022439601</th>
#       <th id="T_a10e7_level1_row6" class="row_heading level1 row6" >ЮРОБАНК БЪЛГАРИЯ АД</th>
#       <td id="T_a10e7_row6_col0" class="data row6 col0" >14,583,000</td>
#       <td id="T_a10e7_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a10e7_level0_row7" class="row_heading level0 row7" >BG28BUIN72201010650432</th>
#       <th id="T_a10e7_level1_row7" class="row_heading level1 row7" >АЛИАНЦ БАНК БЪЛГАРИЯ АД</th>
#       <td id="T_a10e7_row7_col0" class="data row7 col0" >13,409,529</td>
#       <td id="T_a10e7_row7_col1" class="data row7 col1" >48</td>
#     </tr>
#     <tr>
#       <th id="T_a10e7_level0_
col1" >493</td>
#     </tr>
#     <tr>
#       <th id="T_a10e7_level0_row17" class="row_heading level0 row17" >BG50CECB97901009590900</th>
#       <th id="T_a10e7_level1_row17" class="row_heading level1 row17" >ЦЕНТРАЛНА КООПЕРАТИВНА БАНКА АД</th>
#       <td id="T_a10e7_row17_col0" class="data row17 col0" >7,275,702</td>
#       <td id="T_a10e7_row17_col1" class="data row17 col1" >59</td>
#     </tr>
#     <tr>
#       <th id="T_a10e7_level0_row18" class="row_heading level0 row18" >BG05RZBB91551004819781</th>
#       <th id="T_a10e7_level1_row18" class="row_heading level1 row18" >КЕЙ БИ СИ БАНК БЪЛГАРИЯ ЕАД</th>
#       <td id="T_a10e7_row18_col0" class="data row18 col0" >6,929,466</td>
#       <td id="T_a10e7_row18_col1" class="data row18 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_a10e7_level0_row19" class="row_heading level0 row19" >BG05UNCR70001521001399</th>
#       <th id="T_a10e7_level1_row19" class="row_heading level1 row19" >УНИКРЕДИТ БУЛБАНК АД</th>
#       <td id="T_a10e7_row19_col0" class="data row19 col0" >6,658,379</td>
#       <td id="T_a10e7_row19_col1" class="data row19 col1" >48</td>
#     </tr>
#   </tbody>
# </table>

# %%
# This one seems just a BNB IBAN
get_a_report_per_iban(data,"BG40BNBG96611000066123")
# Out:
# [        settlement_date             client_receiver_name  \
#  0            2006-06-06          БЪЛГАРСКА НАРОДНА БАНКА
#  33           2006-07-06          БЪЛГАРСКА НАРОДНА БАНКА
#  345          2006-07-06          БЪЛГАРСКА НАРОДНА БАНКА
#  346          2006-07-06          БЪЛГАРСКА НАРОДНА БАНКА
#  347          2006-07-06          БЪЛГАРСКА НАРОДНА БАНКА
#  ...                 ...                              ...
#  3580248      2022-06-24      МИНИСТЕРСТВО НА ЗЕМЕДЕЛИЕТО
#  3580898      2022-06-24                             УАСГ
#  3581135      2022-06-27  М ВО НА ОБРАЗОВАНИЕТО И НАУКАТА
#  3583660      2022-06-27       БЪЛГАРСКО НАЦИОНАЛНО РАДИО
#  3583839      2022-06-27             МГУ "СВ.ИВАН РИЛСКИ"
#
#              client_receiver_acc client_receiver_bic    fin_code     amount  \
#  0        BG40BNBG96611000066123            BNBGBGSD   100000004   10000.00
#  33       BG40BNBG96611000066123            BNBGBGSD   100000004   10000.00
#  345      BG40BNBG96611000066123            BNBGBGSD   610000000   37610.61
#  346      BG40BNBG96611000066123            BNBGBGSD   610000000  100000.00
#  347      BG40BNBG96611000066123            BNBGBGSD   610000000   18697.73
#  ...                         ...                 ...         ...        ...
#  3580248  BG40BNBG96611000066123            BNBGBGSD   220000002   10000.00
#  3580898  BG40BNBG96611000066123            BNBGBGSD  8160000002    5000.00
#  3581135  BG40BNBG96611000066123            BNBGBGSD   170000005   10000.00
#  3583660  BG40BNBG96611000066123            BNBGBGSD   620000007    7017.22
#  3583839  BG40BNBG96611000066123            BNBGBGSD  8170000000   13000.00
#
#          currency                          reason1         reason2   reg_date  \
#  0            BGN                              NaN             NaN 2006-06-06
#  33           BGN                              NaN             NaN 2006-07-06
#  345          BGN                      П-МО НА БНТ  № 626-02.06.06 2006-07-06
#  346          BGN           ВИОЛЕТКА ЕВГ.АЛЕКСИЕВА             NaN 2006-07-06
#  347          BGN                      П-МО НА БНТ  № 618-01.06.06 2006-07-06
#  ...          ...                              ...             ...        ...
#  3580248      BGN      МИНИСТЕРСТВО НА ЗЕМЕДЕЛИЕТО               , 2022-06-24
#  3580898      BGN                             УАСГ               , 2022-06-24
#  3581135      BGN  М ВО НА ОБРАЗОВАНИЕТО И НАУКАТА               , 2022-06-27
#  3583660      BGN       БЪЛГАРСКО НАЦИОНАЛНО РАДИО               , 2022-06-27
#  3583839      BGN                              NaN               , 2022-06-27
#
#           ... sebra_pay_code                     organization  \
#  0        ...             18  МИНИСТЕРСТВО НА ФИНАНСИТЕ - Ц А
#  33       ...             10  МИНИСТЕРСТВО НА ФИНАНСИТЕ - Ц А
#  345      ...             18                        БНТ-СОФИЯ
#  346      ...             18                        БНТ-СОФИЯ
#  347      ...             18                        БНТ-СОФИЯ
#  ...      ...            ...                              ...
#  3580248  ...             91                         МЗМ - ЦА
#  3580898  ...             91                    УАСГ-РЕКТОРАТ
#  3581135  ...             91          ЦЕНТРАЛНА АДМИНИСТРАЦИЯ
#  3583660  ...             91                         БНР - ЦУ
#  3583839  ...             91                     МГУ-РЕКТОРАТ
#
#                                        primary_organization primary_org_code  \
#  0                                МИНИСТЕРСТВО НА ФИНАНСИТЕ               10
#  33                               МИНИСТЕРСТВО НА ФИНАНСИТЕ               10
#  345                         БЪЛГАРСКА НАЦИОНАЛНА ТЕЛЕВИЗИЯ               61
#  346                         БЪЛГАРСКА НАЦИОНАЛНА ТЕЛЕВИЗИЯ               61
#  347                         БЪЛГАРСКА НАЦИОНАЛНА ТЕЛЕВИЗИЯ               61
#  ...                                                    ...              ...
#  3580248                        МИНИСТЕРСТВО НА ЗЕМЕДЕЛИЕТО               22
#  3580898                УНИВЕРСИТЕТ ПО АРХИТЕКТУРА, СТРОИТЕ              816
#  3581135  МИНИСТЕРСТВО НА ОБРАЗОВАНИЕТО, МЛАДЕЖТА И НАУКАТА               17
#  3583660                         БЪЛГАРСКО НАЦИОНАЛНО РАДИО               62
#  3583839                         МИННО-ГЕОЛОЖКИ УНИВЕРСИТЕТ              817
#
#                                            client_name_hash reg_year  \
#  0        05A51D1B41F7A3355D70E9DEA107795160072499CF3BBE...     2006
#  33       05A51D1B41F7A3355D70E9DEA107795160072499CF3BBE...     2006
#  345      05A51D1B41F7A3355D70E9DEA107795160072499CF3BBE...     2006
#  346      05A51D1B41F7A3355D70E9DEA107795160072499CF3BBE...     2006
#  347      05A51D1B41F7A3355D70E9DEA107795160072499CF3BBE...     2006
#  ...                                                    ...      ...
#  3580248  1A74644A8D5D1A3DC3B098C9D92BDD3CE0D5C7B6107DD7...     2022
#  3580898  E5D87B410C4C1FF853212B14E39B21430247A96047CEBC...     2022
#  3581135  244BF05928A65E752B1937984E84ECD27C4099E96AD026...     2022
#  3583660  2CFB6F12D30DF864E7641F9F70E507BDBA3297F150D31D...     2022
#  3583839  C04CABF63D5801F7B99B499034D5340DE78D687D214B87...     2022
#
#           government_alias               government_pm   party/coalition  \
#  0                СТАНИШЕВ  СЕРГЕЙ СТАНИШЕВ(РОД. 1966)    БСП, НДСВ, ДПС
#  33               СТАНИШЕВ  СЕРГЕЙ СТАНИШЕВ(РОД. 1966)    БСП, НДСВ, ДПС
#  345              СТАНИШЕВ  СЕРГЕЙ СТАНИШЕВ(РОД. 1966)    БСП, НДСВ, ДПС
#  346              СТАНИШЕВ  СЕРГЕЙ СТАНИШЕВ(РОД. 1966
#         'E9D250E2FF95F801CD5243AB92D32CBE6B683555E2621D90408177D73E03D7AB',
#         'B2AF813E4792A0A4DEAD7E8FEED49B8DAC9695375B3A03FD57A0281E11C4A8F1',
#         'B80DB1E8636E8D08ABA55A84C9CB8B64085813AEBD48D456A32ECE15732A7E94',
#         '8E918E39922C3872DC4E03BBB59DCB9DA06321F7BF29C0E6EA3DA94E672FD8C7',
#         'BDAD9B34C278096751B4B10FDFAF928BF2FF0B7AD5B8B6BC6A9CC6E57392EAB6'],
#        dtype=object),
#  array(['БЪЛГАРСКА НАРОДНА БАНКА', 'БНБ', 'ДИАНА ЗИДАРОВА',
#         'ВИОЛЕТА ВЕЛИНОВА', 'ФИЗИЧЕСКО ЛИЦЕ', 'ВЕСЕЛИНКА АТАНАСОВА',
#         'АННА ЕФТИМОВА', 'СЛАВЧО СТОЯНОВ', 'ТЕОДОРА ТЕНЧЕВА ИВАНОВА',
#         'DUMMY COUNTERPARTY FOR TRANSACTIONS', 'БНБ ЦУ',
#         'ТЕОДОРА НИКОЛОВА ХРИСТОВА', 'ЕМИЛИЯ ВАСИЛЕВА',
#         'ЛИЛИЯ ЙОРДАНОВАА КЪРЖИЛОВА', 'МОМН', 'КОМИС.ЗА РЕГУЛ.НА СЪОБЩЕН.',
#         'НСА "В.ЛЕВСКИ"', 'АДМ. НА ПРЕЗИДЕНТА НА РБ',
#         'МИНИСТЕРСТВО НА ФИНАНСИТЕ', 'НСИ', 'БЪЛГАРСКО НАЦИОНАЛНО РАДИО',
#         'М ВО НА ИКОНОМИКАТА,ЕНЕРГ.И ТУРИЗМА',
#         'КОМИСИЯЗАЗАЩИТАОТДИСКРИМИН', 'К.ЗА З ТА НА КОНКУРЕНЦИЯТА',
#         'НМА"ПРОФ.ПАНЧО ВЛАДИГЕРОВ"', 'БАН   ЦЕНТРАЛНО УПРАВЛЕНИЕ',
#         'НАРОДНО СЪБРАНИЕ', 'М ВО НА ИКОНОМИКАТА И ЕНЕРГЕТИКАТА',
#         'БЪЛГАРСКА ТЕЛЕГРАФНА АГЕНЦИЯ', 'М ВО НА ОК.СРЕДА И ВОДИТЕ', 'МРР',
#         'НАЦИОН.ЗДРАВНООСИГУР.КАСА', 'УАСГ', 'ХТМУ', 'АВИООТРЯД 28',
#         'М ВО НА ВЪНШНИТЕ РАБОТИ', 'М ВО НА ПРАВОСЪДИЕТО',
#         'М ВО НА ТРУДА И СОЦ.ПОЛИТ.', 'М ВО НА ЗДРАВЕОПАЗВАНЕТО',
#         'М ВО НА КУЛТУРАТА', 'МЗХ', 'АГЕНЦИЯ ЗА ЯДРЕНО РЕГУЛИР.',
#         'МИНИСТЕРСКИ СЪВЕТ', 'ТЕХНИЧЕСКИ УНИВЕРСИТЕТ',
#         'ВИСШ СЪДЕБЕН СЪВЕТ', 'БНТ', 'М ВО НА ОБРАЗОВАНИЕТО И НАУКАТА',
#         'НХА', 'КПУКИ', 'КОМИСИЯ ЗА ФИНАНСОВ НАДЗОР',
#         'МИНИСТЕРСТВО НА МЛАДЕЖТА И СПОРТА', 'ДКЕВР',
#         'МИНИСТЕРСТВО НА ТРАНСП.ИНФ.ТЕХНОЛ.', 'СМЕТНА ПАЛАТА',
#         'КОМИСИЯ ПО ДОСИЕТАТА', 'СЪВЕТ ЗА ЕЛЕКТРОННИ МЕДИИ', 'ДА ДРВВЗ',
#         'ЦЕНТРАЛНА ИЗБИРАТЕЛНА КОМИСИЯ', 'НОИ',
#         'М ВО НА ИНВЕСТИЦИОННОТО ПРОЕКТИРАНЕ', 'К Я ЗА ЗАЩИТАНАЛИЧН.ДАННИ',
#         'ВТУ "ТОДОР КАБЛЕШКОВ"', 'МРРБ', 'КОНПИ',
#         'МИНИСТЕРСТВО НА ИКОНОМИКАТА', 'МИНИСТЕРСТВО НА ТУРИЗМА',
#         'НАТФИЗ КРЪСТЮ САРАФОВ', 'МИНИСТЕРСТВО НА ЕНЕРГЕТИКАТА', 'УНСС',
#         'КЕВР', 'МГУ "СВ.ИВАН РИЛСКИ"', 'ДФ "ЗЕМЕДЕЛИЕ"', 'НБКСРС',
#         'ОМБУДСМАН', 'ДА "ЕЛЕКТРОННО УПРАВЛЕНИЕ"',
#         'К ЯЗАПУБЛ.НАДЗОРНАДРЕГИСТР.ОДИТОРИ', 'ВУ ПО ТЕЛЕКОМУНИК. И ПОЩИ',
#         'МЗХГ', 'МБПСЕС 2018', 'КПКОНПИ', 'КАСОВО ПОДАРАЗДЕЛЕНИЕ',
#         'ДЪРЖАВНО ПРЕДПРИЯТИЕ "УПРАВЛЕНИЕ И',
#         'МИНИСТЕРСТВО НА ЗЕМЕДЕЛИЕТО', 'МИНИСТЕРСТВО НА СПОРТА', 'М Т С',
#         'М ВО НА ИКОНОМИКАТА И ИНДУСТРИЯТА', 'СЕЛСКОСТОПАНСКА АКАДЕМИЯ',
#         'МИНИСТЕРСТВО НА ЕЛЕКТРОННОТО УПРАВЛ'], dtype=object),
#                                                              sum  count
#  primary_organization                      reg_year
#  МИНИСТЕРСТВО НА ФИНАНСИТЕ                 2006      35466883.44    196
#  ТЕХНИЧЕСКИ УНИВЕРСИТЕТ - СОФИЯ            2006         48916.03      6
#  СЪВЕТ ЗА ЕЛЕКТРОННИ МЕДИИ                 2006         10000.00      1
#  БЪЛГАРСКА НАЦИОНАЛНА ТЕЛЕВИЗИЯ            2006       9701922.86    129
#  СМЕТНА ПАЛАТА                             2006        240000.00     18
#  ...                                                         ...    ...
#  НЗОК                                      2022         60000.00      2
#  МИНИСТЕРСТВО НА ИКОНОМИКАТА               2022        157855.04      6
#  МИНИСТЕРСТВО НА ИКОНОМИКАТА И ИНДУСТРИЯТА 2022         71818.08      8
#  КОМИСИЯ ЗА ФИНАНСОВ НАДЗОР                2022         75514.13     13
#  ЦЕНТРАЛНА ИЗБИРАТЕЛНА КОМИСИЯ             2022         50500.00      7
#
#  [780 rows x 2 columns]]

# %%
# This one seems just БДЖ
get_a_report_per_iban(data,"BG95BPBI79421076516501")
# Out:
# [        settlement_date         client_receiver_name     client_receiver_acc  \
#  1126368      2013-02-14               ФИЗИЧЕСКО ЛИЦЕ  BG95BPBI79421076516501
#  1126369      2013-02-14               ФИЗИЧЕСКО ЛИЦЕ  BG95BPBI79421076516501
#  1154496      2013-03-13               ФИЗИЧЕСКО ЛИЦЕ  BG95BPBI79421076516501
#  1170181      2013-10-04               ФИЗИЧЕСКО ЛИЦЕ  BG95BPBI79421076516501
#  1189348      2013-10-05               ФИЗИЧЕСКО ЛИЦЕ  BG95BPBI79421076516501
#  ...                 ...                          ...                     ...
#  2404239      2018-07-08  БДЖ ПЪТНИЧЕСКИ ПРЕВОЗИ ЕООД  BG95BPBI79421076516501
#  2422858      2018-11-09  БДЖ ПЪТНИЧЕСКИ ПРЕВОЗИ ЕООД  BG95BPBI79421076516501
#  2439940      2018-12-10  БДЖ ПЪТНИЧЕСКИ ПРЕВОЗИ ЕООД  BG95BPBI79421076516501
#  2457670      2018-12-11  БДЖ ПЪТНИЧЕСКИ ПРЕВОЗИ ЕООД  BG95BPBI79421076516501
#  2470524      2018-11-30  БДЖ ПЪТНИЧЕСКИ ПРЕВОЗИ ЕООД  BG95BPBI79421076516501
#
#          client_receiver_bic   fin_code       amount currency  \
#  1126368            BPBIBGSF  230000000  14166000.00      BGN
#  1126369            BPBIBGSF  230000000  14166000.00      BGN
#  1154496            BPBIBGSF  230000000  13859875.00      BGN
#  1170181            BPBIBGSF  230000000  14166000.00      BGN
#  1189348            BPBIBGSF  230000000  14166000.00      BGN
#  ...                     ...        ...          ...      ...
#  2404239            BPBIBGSF  230000000  14583000.00      BGN
#  2422858            BPBIBGSF  230000000  14440875.23      BGN
#  2439940            BPBIBGSF  230000000  14421947.37      BGN
#  2457670            BPBIBGSF  230000000  14583000.00      BGN
#  2470524            BPBIBGSF  230000000  14456917.78      BGN
#
#                              reason1                     reason2   reg_date  \
#  1126368  СУБСИДИЯ ПО ЧЛ10 АЛ.3 ПМС1         09.01.13    М01.13Г 2013-02-13
#  1126369  СУБСИДИЯ ПО ЧЛ10 АЛ.3 ПМС1            09.01.13 М02.13Г 2013-02-13
#  1154496      СУБСИДИЯ ЗА М.03.2013Г                         NaN 2013-06-03
#  1170181  СУБСИДИЯ ПО ЧЛ.10 АЛ.3 ПМС        1/09.01.13 М.04/2013 2013-09-04
#  1189348  СУБСИДИЯ ПО ЧЛ10 АЛ3 ПМС1/        09.01.13  М.МАЙ 2013 2013-09-05
#  ...                             ...                         ...        ...
#  2404239     СУБСИДИЯ ЗА   М.08/2018  0818 0818910 21 195 020818 2018-06-08
#  2422858    СУБСИДИЯ      М. 09.2018  0918 0918910 21 220 310818 2018-10-09
#  2439940          СУБСИДИЯ М.10 2018  1018 1018910 21 249 031018 2018-11-10
#  2457670    СУБСИДИЯ      М. 11/2018  1118 1118910 21 273 011118 2018-09-11
#  2470524        СУБСИДИЯ М.12 2018 Г  1218 1218910 21 301 261118 2018-11-29
#
#           ... sebra_pay_code                   organization  \
#  1126368  ...             10  МИНИСТЕРСТВО НА ТРАНСПОРТА-ЦА
#  1126369  ...             10  МИНИСТЕРСТВО НА ТРАНСПОРТА-ЦА
#  1154496  ...             30  МИНИСТЕРСТВО НА ТРАНСПОРТА-ЦА
#  1170181  ...             30  МИНИСТЕРСТВО НА ТРАНСПОРТА-ЦА
#  1189348  ...             30  МИНИСТЕРСТВО НА ТРАНСПОРТА-ЦА
#  ...      ...            ...                            ...
#  2404239  ...             30  МИНИСТЕРСТВО НА ТРАНСПОРТА-ЦА
#  2422858  ...             30  МИНИСТЕРСТВО НА ТРАНСПОРТА-ЦА
#  2439940  ...             30  МИНИСТЕРСТВО НА ТРАНСПОРТА-ЦА
#  2457670  ...             30  МИНИСТЕРСТВО НА ТРАНСПОРТА-ЦА
#  2470524  ...             30  МИНИСТЕРСТВО НА ТРАНСПОРТА-ЦА
#
#                 primary_organization primary_org_code  \
#  1126368  МИНИСТЕРСТВО НА ТРАНСПОРТА               23
#  1126369  МИНИСТЕРСТВО НА ТРАНСПОРТА               23
#  1154496  МИНИСТЕРСТВО НА ТРАНСПОРТА               23
#  1170181  МИНИСТЕРСТВО НА ТРАНСПОРТА               23
#  1189348  МИНИСТЕРСТВО НА ТРАНСПОРТА               23
#  ...                             ...              ...
#  2404239  МИНИСТЕРСТВО НА ТРАНСПОРТА               23
#  2422858  МИНИСТЕРСТВО НА ТРАНСПОРТА               23
#  2439940  МИНИСТЕРСТВО НА ТРАНСПОРТА               23
#  2457670  МИНИСТЕРСТВО НА ТРАНСПОРТА               23
#  2470524  МИНИСТЕРСТВО НА ТРАНСПОРТА               23
#
#                                            client_name_hash reg_year  \
#  1126368  7E5DF5ED143B19885C4195ACD5D0C83CF102C7ED942AD3...     2013
#  1126369  7E5DF5ED143B19885C4195ACD5D0C83CF102C7ED942AD3...     2013
#  1154496  7E5DF5ED143B19885C4195ACD5D0C83CF102C7ED942AD3...     2013
#  1170181  7E5DF5ED143B19885C4195ACD5D0C83CF102C7ED942AD3...     2013
#  1189348  7E5DF5ED143B19885C4195ACD5D0C83CF102C7ED942AD3...     2013
#  ...                                                    ...      ...
#  2404239  C7CA3B8B911C6FC4EE7347C3537E8A6A48441E85CA1CBF...     2018
#  2422858  C7CA3B8B911C6FC4EE7347C3537E8A6A48441E85CA1CBF...     2018
#  2439940  C7CA3B8B911C6FC4EE7347C3537E8A6A48441E85CA1CBF...     2018
#  2457670  C7CA3B8B911C6FC4EE7347C3537E8A6A48441E85CA1CBF...     2018
#  2470524  C7CA3B8B911C6FC4EE7347C3537E8A6A48441E85CA1CBF...     2018
#
#           government_alias                government_pm  \
#  1126368         БОРИСОВ 1     БОЙКО БОРИСОВ(РОД. 1959)
#  1126369         БОРИСОВ 1     БОЙКО БОРИСОВ(РОД. 1959)
#  1154496         БОРИСОВ 1     БОЙКО БОРИСОВ(РОД. 1959)
#  1170181         ОРЕШАРСКИ  ПЛАМЕН ОРЕШАРСКИ(РОД. 1960)
#  1189348         ОРЕШАРСКИ  ПЛАМЕН ОРЕШАРСКИ(РОД. 1960)
#  ...                   ...                          ...
#  2404239         БОРИСОВ 3     БОЙКО БОРИСОВ(РОД. 1959)
#  2422858         БОРИСОВ 3     БОЙКО БОРИСОВ(РОД. 1959)
#  2439940         БОРИСОВ 3     БОЙКО БОРИСОВ(РОД. 1959)
#  2457670         БОРИСОВ 3     БОЙКО БОРИСОВ(РОД. 1959)
#  2470524         БОРИСОВ 3     БОЙКО БОРИСОВ(РОД. 1959)
#
#                    party/coalition            bank_name
#  1126368                   ГЕРБ[3]  ЮРОБАНК БЪЛГАРИЯ АД
#  1126369                   ГЕРБ[3]  ЮРОБАНК БЪЛГАРИЯ АД
#  1154496                   ГЕРБ[3]  ЮРОБАНК БЪЛГАРИЯ АД
#  1170181               БСП, ДПС[4]  ЮРОБАНК БЪЛГАРИЯ АД
#  1189348               БСП, ДПС[4]  ЮРОБАНК БЪЛГАРИЯ АД
#  ...                           ...                  ...
#  2404239  ГЕРБ, ОБЕДИНЕНИ ПАТРИОТИ  ЮРОБАНК БЪЛГАРИЯ АД
#  2422858  ГЕРБ, ОБЕДИНЕНИ ПАТРИОТИ  ЮРОБАНК БЪЛГАРИЯ АД
#  2439940  ГЕРБ, ОБЕДИНЕНИ ПАТРИОТИ  ЮРОБАНК БЪЛГАРИЯ АД
#  2457670  ГЕРБ, ОБЕДИНЕНИ ПАТРИОТИ  ЮРОБАНК БЪЛГАРИЯ АД
#  2470524  ГЕРБ, ОБЕДИНЕНИ ПАТРИОТИ  ЮРОБАНК БЪЛГАРИЯ АД
#
#  [70 rows x 21 columns],
#  array(['7E5DF5ED143B19885C4195ACD5D0C83CF102C7ED942AD320101BF367064760DF',
#         'ADA5F5EF85BFF2FF5F9E7C50F09FFE8FC3B18D27D5BA81DDAC5F9D34ECA4374F',
#         '4E394376A7300845D0718B20F4FF9E1EEFA2A56950F58B0C7D5CACC9496E236B',
#         'C7CA3B8B911C6FC4EE7347C3537E8A6A48441E85CA1CBF8D1C78015609A63FF0',
#         'C5A59A27A78C540A8A12B7B64841B2912F93B8874007F7FBBBA44A33F2B3794C'],
#        dtype=object),
#  array(['ФИЗИЧЕСКО ЛИЦЕ', 'БДЖ ПЪТНИЧЕСКИ ПРЕВОЗИ ЕОО',
#         'БДЖ ПЪТНИЧЕСКИ ПРЕВОЗИЕООД', 'БДЖ ПЪТНИЧЕСКИ ПРЕВОЗИ ЕООД',
#         'БДЖПЪТНИЧЕСКИ ПРЕВОЗИ ЕООД'], dtype=object),
#                                                sum  count
#  primary_organization       reg_year
#  МИНИСТЕРСТВО НА ТРАНСПОРТА 2013      1.693182e+08     12
#                             2014      1.591513e+08     12
#                             2015      1.797911e+08     12
#                             2016      1.746132e+08     12
#                             2017      1.731169e+08     12
#                             2018      1.452350e+08     10]

# %%
# This is just Rakitovo's municipality
get_a_report_per_iban(data, "BG52RZBB91553120008113")
# Out:
# [        settlement_date client_receiver_name     client_receiver_acc  \
#  2582835      2019-04-19         ОБЩИНА ТРОЯН  BG52RZBB91553120008113
#  2584642      2019-04-19       ФИЗИЧЕСКО ЛИЦЕ  BG52RZBB91553120008113
#  2591031      2019-04-24       ФИЗИЧЕСКО ЛИЦЕ  BG52RZBB91553120008113
#  2606842      2019-07-05       ФИЗИЧЕСКО ЛИЦЕ  BG52RZBB91553120008113
#  2608373      2019-09-05       ФИЗИЧЕСКО ЛИЦЕ  BG52RZBB91553120008113
#  ...                 ...                  ...                     ...
#  3561640      2022-06-06       ФИЗИЧЕСКО ЛИЦЕ  BG52RZBB91553120008113
#  3566693      2022-06-15         ОБЩИНА ТРОЯН  BG52RZBB91553120008113
#  3577206      2022-06-20         ОБЩИНА ТРОЯН  BG52RZBB91553120008113
#  3577900      2022-06-21         ОБЩИНА ТРОЯН  BG52RZBB91553120008113
#  3583777      2022-06-27       ФИЗИЧЕСКО ЛИЦЕ  BG52RZBB91553120008113
#
#          client_receiver_bic    fin_code      amount currency  \
#  2582835            RZBBBGSF   153000004    27782.92      BGN
#  2584642            RZBBBGSF  4442060000  1063364.00      BGN
#  2591031            RZBBBGSF  4442060000    10212.00      BGN
#  2606842            RZBBBGSF  4442060000    18173.00      BGN
#  2608373            RZBBBGSF  4442060000   921385.00      BGN
#  ...                     ...         ...         ...      ...
#  3561640            RZBBBGSF  4442060102   133911.00      BGN
#  3566693            RZBBBGSF   153000004     7214.48      BGN
#  3577206            RZBBBGSF   153000004   157449.53      BGN
#  3577900            RZBBBGSF   150090004    11550.00      BGN
#  3583777            RZBBBGSF  4442060000    47346.00      BGN
#
#                           reason1                     reason2   reg_date  ...  \
#  2582835                   ПМС344  0319 03199ФС01 0555 281218 2019-04-18  ...
#  2584642  ОБЩА ДОПЪЛВАЩА СУБСИДИЯ                           9 2019-04-18  ...
#  2591031  ОБЩА ДОПЪЛВАЩА СУБСИДИЯ                           9 2019-04-23  ...
#  2606842  ОБЩА ДОПЪЛВАЩА СУБСИДИЯ                           9 2019-03-05  ...
#  2608373        ОБЩА ДОП.СУБСИДИЯ                           9 2019-08-05  ...
#  ...                          ...                         ...        ...  ...
#  3561640    ИЗРАВНИТЕЛНА СУБСИДИЯ                           9 2022-03-06  ...
#  3566693      ПРИЕМНА ГРИЖА 2022Г  0522 05229ТРАНСФЕР  130522 2022-06-14  ...
#  3577206              ЛИЧНА ПОМОЩ  0522 05229ФС01 0294 310719 2022-06-16  ...
#  3577900               ТРАПЕЗАРИЯ  0622 0622915        200622 2022-06-20  ...
#  3583777  ОБЩА ДОПЪЛВАЩА СУБСИДИЯ              9 ФО-30 210622 2022-06-24  ...
#
#          sebra_pay_code                 organization  \
#  2582835             60                     АСП - ЦУ
#  2584642             60        ТРОЯН - ОБЩА СУБСИДИЯ
#  2591031             60        ТРОЯН - ОБЩА СУБСИДИЯ
#  2606842             60        ТРОЯН - ОБЩА СУБСИДИЯ
#  2608373             60        ТРОЯН - ОБЩА СУБСИДИЯ
#  ...                ...                          ...
#  3561640             10  ТРОЯН - С-Я МЕСТНИ ДЕЙНОСТИ
#  3566693             60                     АСП - ЦУ
#  3577206             60                     АСП - ЦУ
#  3577900             40        ФОНД СОЦИАЛНА ЗАКРИЛА
#  3583777             60        ТРОЯН - ОБЩА СУБСИДИЯ
#
#                                  primary_organization primary_org_code  \
#  2582835  МИНИСТЕРСТВО НА ТРУДА И СОЦИАЛНАТА ПОЛИТИКА               15
#  2584642                      ЦБ - СУБСИДИИ ЗА ОБЩИНИ              444
#  2591031                      ЦБ - СУБСИДИИ ЗА ОБЩИНИ              444
#  2606842                      ЦБ - СУБСИДИИ ЗА ОБЩИНИ              444
#  2608373                      ЦБ - СУБСИДИИ ЗА ОБЩИНИ              444
#  ...                                              ...              ...
#  3561640                      ЦБ - СУБСИДИИ ЗА ОБЩИНИ              444
#  3566693  МИНИСТЕРСТВО НА ТРУДА И СОЦИАЛНАТА ПОЛИТИКА               15
#  3577206  МИНИСТЕРСТВО НА ТРУДА И СОЦИАЛНАТА ПОЛИТИКА               15
#  3577900  МИНИСТЕРСТВО НА ТРУДА И СОЦИАЛНАТА ПОЛИТИКА               15
#  3583777                      ЦБ - СУБСИДИИ ЗА ОБЩИНИ              444
#
#                                            client_name_hash reg_year  \
#  2582835  119D52F3C47FD545376FC76C1A469BE406483137E1B3A5...     2019
#  2584642  8CC8F3B044B08EF8881D564854AD8D067BA9FF7A25BA99...     2019
#  2591031  8CC8F3B044B08EF8881D564854AD8D067BA9FF7A25BA99...     2019
#  2606842  8CC8F3B044B08EF8881D564854AD8D067BA9FF7A25BA99...     2019
#  2608373  8CC8F3B044B08EF8881D564854AD8D067BA9FF7A25BA99...     2019
#  ...                                                    ...      ...
#  3561640  8CC8F3B044B08EF8881D564854AD8D067BA9FF7A25BA99...     2022
#  3566693  119D52F3C47FD545376FC76C1A469BE406483137E1B3A5...     2022
#  3577206  119D52F3C47FD545376FC76C1A469BE406483137E1B3A5...     2022
#  3577900  119D52F3C47FD545376FC76C1A469BE406483137E1B3A5...     2022
#  3583777  8CC8F3B044B08EF8881D564854AD8D067BA9FF7A25BA99...     2022
#
#           government_alias             government_pm           party/coalition  \
#  2582835         БОРИСОВ 3  БОЙКО БОРИСОВ(РОД. 1959)  ГЕРБ, ОБЕДИНЕНИ ПАТРИОТИ
#  2584642         БОРИСОВ 3  БОЙКО БОРИСОВ(РОД. 1959)  ГЕРБ, ОБЕДИНЕНИ ПАТРИОТИ
#  2591031         БОРИСОВ 3  БОЙКО БОРИСОВ(РОД. 1959)  ГЕРБ, ОБЕДИНЕНИ ПАТРИОТИ
#  2606842         БОРИСОВ 3  БОЙКО БОРИСОВ(РОД. 1959)  ГЕРБ, ОБЕДИНЕНИ ПАТРИОТИ
#  2608373         БОРИСОВ 3  БОЙКО БОРИСОВ(РОД. 1959)  ГЕРБ, ОБЕДИНЕНИ ПАТРИОТИ
#  ...                   ...                       ...                       ...
#  3561640         К. ПЕТКОВ   КИРИЛ ПЕТКОВ(РОД. 1980)          ПП, БСП, ИТН, ДБ
#  3566693         К. ПЕТКОВ   КИРИЛ ПЕТКОВ(РОД. 1980)          ПП, БСП, ИТН, ДБ
#  3577206         К. ПЕТКОВ   КИРИЛ ПЕТКОВ(РОД. 1980)          ПП, БСП, ИТН, ДБ
#  3577900         К. ПЕТКОВ   КИРИЛ ПЕТКОВ(РОД. 1980)          ПП, БСП, ИТН, ДБ
#  3583777         К. ПЕТКОВ   КИРИЛ ПЕТКОВ(РОД. 1980)          ПП, БСП, ИТН, ДБ
#
#                             bank_name
#  2582835  КЕЙ БИ СИ БАНК БЪЛГАРИЯ ЕАД
#  2584642  КЕЙ БИ СИ БАНК БЪЛГАРИЯ ЕАД
#  2591031  КЕЙ БИ СИ БАНК БЪЛГАРИЯ ЕАД
#  2606842  КЕЙ БИ СИ БАНК БЪЛГАРИЯ ЕАД
#  2608373  КЕЙ БИ СИ БАНК БЪЛГАРИЯ ЕАД
#  ...                              ...
#  3561640  КЕЙ БИ СИ БАНК БЪЛГАРИЯ ЕАД
#  3566693  КЕЙ БИ СИ БАНК БЪЛГАРИЯ ЕАД
#  3577206  КЕЙ БИ СИ БАНК БЪЛГАРИЯ ЕАД
#  3577900  КЕЙ БИ СИ БАНК БЪЛГАРИЯ ЕАД
#  3583777  КЕЙ БИ СИ БАНК БЪЛГАРИЯ ЕАД
#
#  [204 rows x 21 columns],
#  array(['119D52F3C47FD545376FC76C1A469BE406483137E1B3A5F9307EF9AE0C4B14B4',
#         '8CC8F3B044B08EF8881D564854AD8D067BA9FF7A25BA99979F5FA8B8C650D771',
#         '09FD7AC2CB8D618D175A3AFA0BC38DDD6DAC627C468D649743D9493717104CBF',
#         '0998DD5391C5C2104EF1576E600EFA35BDCD932D37B4D122883437E5E1FF3A5D',
#         '2793D98BF181067BE8FA7A68DEC7D685458BA646E317C3BBB3A599F4914E7F00'],
#        dtype=object),
#  array(['ОБЩИНА ТРОЯН', 'ФИЗИЧЕСКО ЛИЦЕ',
#         'TROYAN MUNICIPALITY YURIDICHESKO LI', '6106 ОБЩИНА ТРОЯН'],
#        dtype=object),
#                                                                sum  count
#  primary_organization                        reg_year
#  МИНИСТЕРСТВО НА ТРУДА И СОЦИАЛНАТА ПОЛИТИКА 2019        341767.60     15
#  МОСВ-ЧУЖДИ СРЕДСТВА                         2019        166200.00      1
#  ЦБ - СУБСИДИИ ЗА ОБЩИНИ                     2019      10104364.06     26
#  МИНИСТЕРСТВО НА ТРУДА И СОЦИАЛНАТА ПОЛИТИКА 2020       1036470.40     19
#  МОСВ-ЧУЖДИ СРЕДСТВА                         2020       1590415.72      2
#  ЦБ - СУБСИДИИ ЗА ОБЩИНИ                     2020      17635775.00     28
#  МИНИСТЕРСТВО НА РЕГИОНАЛНОТО РАЗВИТ         2021        650000.00      1
#  МИНИСТЕРСТВО НА ТРУДА И СОЦИАЛНАТА ПОЛИТИКА 2021       1459640.64     40
#  МОСВ-ЧУЖДИ СРЕДСТВА                         2021       1016073.45      4
#  ЦБ - СУБСИДИИ ЗА ОБЩИНИ                     2021      19381823.63     36
#  МИНИСТЕРСТВО НА ТРУДА И СОЦИАЛНАТА ПОЛИТИКА 2022       1016338.32     20
#  ЦБ - СУБСИДИИ ЗА ОБЩИНИ                     2022      11933190.00     12]

# %%
# This is just Troyan's municipality
get_a_report_per_iban(data, "BG26RZBB91553100055002")
# Out:
# [        settlement_date client_receiver_name     client_receiver_acc  \
#  2200601      2017-03-11       ФИЗИЧЕСКО ЛИЦЕ  BG26RZBB91553100055002
#  2202794      2017-07-11       ФИЗИЧЕСКО ЛИЦЕ  BG26RZBB91553100055002
#  2207136      2017-11-15       ФИЗИЧЕСКО ЛИЦЕ  BG26RZBB91553100055002
#  2209880      2017-11-22      ОБЩИНА РАКИТОВО  BG26RZBB91553100055002
#  2212311      2017-11-27       ФИЗИЧЕСКО ЛИЦЕ  BG26RZBB91553100055002
#  ...                 ...                  ...                     ...
#  3542892      2022-05-19      ОБЩИНА РАКИТОВО  BG26RZBB91553100055002
#  3564694      2022-10-06       ФИЗИЧЕСКО ЛИЦЕ  BG26RZBB91553100055002
#  3566684      2022-06-15      ОБЩИНА РАКИТОВО  BG26RZBB91553100055002
#  3577210      2022-06-20      ОБЩИНА РАКИТОВО  BG26RZBB91553100055002
#  3580839      2022-06-24       ФИЗИЧЕСКО ЛИЦЕ  BG26RZBB91553100055002
#
#          client_receiver_bic    fin_code     amount currency  \
#  2200601            RZBBBGSF  4442490000  460000.00      BGN
#  2202794            RZBBBGSF  4442490000   30000.00      BGN
#  2207136            RZBBBGSF  4442490103  120000.00      BGN
#  2209880            RZBBBGSF   153000004   23666.13      BGN
#  2212311            RZBBBGSF  4442490000  100000.00      BGN
#  ...                     ...         ...        ...      ...
#  3542892            RZBBBGSF   153000004   68404.28      BGN
#  3564694            RZBBBGSF  4442490103  300000.00      BGN
#  3566684            RZBBBGSF   153000004   13451.20      BGN
#  3577210            RZBBBGSF   153000004   70358.68      BGN
#  3580839            RZBBBGSF  4442490000  150000.00      BGN
#
#                            reason1                     reason2   reg_date  ...  \
#  2200601             ОБЩА СУБСИДИЯ                   1117 1117 2017-02-11  ...
#  2202794             ОБЩА СУБСИДИЯ                   1117 1117 2017-06-11  ...
#  2207136  ТРАНСФЕР МЕСТНИ ДЕЙНОСТИ                   1117 1117 2017-11-14  ...
#  2209880                   ПМС 137  1017 10179ФС01 0087 020817 2017-11-21  ...
#  2212311             ОБЩА СУБСИДИЯ                   1117 1117 2017-11-24  ...
#  ...                           ...                         ...        ...  ...
#  3542892               ЛИЧНА ПОМОЩ  0422 04229ФС01 0299 310719 2022-05-18  ...
#  3564694  ТРАНСФЕР МЕСТНИ ДЕЙНОСТИ                   0622 0622 2022-09-06  ...
#  3566684       ПРИЕМНА ГРИЖА 2022Г  0522 05229ТРАНСФЕР  130522 2022-06-14  ...
#  3577210               ЛИЧНА ПОМОЩ  0522 05229ФС01 0299 310719 2022-06-16  ...
#  3580839             ОБЩА СУБСИДИЯ                   0622 0622 2022-06-23  ...
#
#          sebra_pay_code                    organization  \
#  2200601             60        РАКИТОВО - ОБЩА СУБСИДИЯ
#  2202794             60        РАКИТОВО - ОБЩА СУБСИДИЯ
#  2207136             10  РАКИТОВО - С-Я МЕСТНИ ДЕЙНОСТИ
#  2209880             60                        АСП - ЦУ
#  2212311             60        РАКИТОВО - ОБЩА СУБСИДИЯ
#  ...                ...                             ...
#  3542892             60                        АСП - ЦУ
#  3564694             10  РАКИТОВО - С-Я МЕСТНИ ДЕЙНОСТИ
#  3566684             60                        АСП - ЦУ
#  3577210             60                        АСП - ЦУ
#  3580839             60        РАКИТОВО - ОБЩА СУБСИДИЯ
#
#                                  primary_organization primary_org_code  \
#  2200601                      ЦБ - СУБСИДИИ ЗА ОБЩИНИ              444
#  2202794                      ЦБ - СУБСИДИИ ЗА ОБЩИНИ              444
#  2207136                      ЦБ - СУБСИДИИ ЗА ОБЩИНИ              444
#  2209880  МИНИСТЕРСТВО НА ТРУДА И СОЦИАЛНАТА ПОЛИТИКА               15
#  2212311                      ЦБ - СУБСИДИИ ЗА ОБЩИНИ              444
#  ...                                              ...              ...
#  3542892  МИНИСТЕРСТВО НА ТРУДА И СОЦИАЛНАТА ПОЛИТИКА               15
#  3564694                      ЦБ - СУБСИДИИ ЗА ОБЩИНИ              444
#  3566684  МИНИСТЕРСТВО НА ТРУДА И СОЦИАЛНАТА ПОЛИТИКА               15
#  3577210  МИНИСТЕРСТВО НА ТРУДА И СОЦИАЛНАТА ПОЛИТИКА               15
#  3580839                      ЦБ - СУБСИДИИ ЗА ОБЩИНИ              444
#
#                                            client_name_hash reg_year  \
#  2200601  96C701EEC49C76B8805B8A39A27BA659973FFC7C585692...     2017
#  2202794  96C701EEC49C76B8805B8A39A27BA659973FFC7C585692...     2017
#  2207136  96C701EEC49C76B8805B8A39A27BA659973FFC7C585692...     2017
#  2209880  68772E1ADEC12A9CCB1E274421C0144A1AC5EBAECC8756...     2017
#  2212311  96C701EEC49C76B8805B8A39A27BA659973FFC7C585692...     2017
#  ...                                                    ...      ...
#  3542892  68772E1ADEC12A9CCB1E274421C0144A1AC5EBAECC8756...     2022
#  3564694  96C701EEC49C76B8805B8A39A27BA659973FFC7C585692...     2022
#  3566684  68772E1ADEC12A9CCB1E274421C0144A1AC5EBAECC8756...     2022
#  3577210  68772E1ADEC12A9CCB1E274421C0144A1AC5EBAECC8756...     2022
#  3580839  96C701EEC49C76B8805B8A39A27BA659973FFC7C585692...     2022
#
#           government_alias               government_pm  \
#  2200601         ГЕРДЖИКОВ  ОГНЯН ГЕРДЖИКОВ(РОД. 1946)
#  2202794         БОРИСОВ 3    БОЙКО БОРИСОВ(РОД. 1959)
#  2207136         БОРИСОВ 3    БОЙКО БОРИСОВ(РОД. 1959)
#  2209880         БОРИСОВ 3    БОЙКО БОРИСОВ(РОД. 1959)
#  2212311         БОРИСОВ 3    БОЙКО БОРИСОВ(РОД. 1959)
#  ...                   ...                         ...
#  3542892         К. ПЕТКОВ     КИРИЛ ПЕТКОВ(РОД. 1980)
#  3564694               NaN                         NaN
#  3566684         К. ПЕТКОВ     КИРИЛ ПЕТКОВ(РОД. 1980)
#  3577210         К. ПЕТКОВ     КИРИЛ ПЕТКОВ(РОД. 1980)
#  3580839         К. ПЕТКОВ     КИРИЛ ПЕТКОВ(РОД. 1980)
#
#                    party/coalition                    bank_name
#  2200601      СЛУЖЕБЕН; НЕЗАВИСИМИ  КЕЙ БИ СИ БАНК БЪЛГАРИЯ ЕАД
#  2202794  ГЕРБ, ОБЕДИНЕНИ ПАТРИОТИ  КЕЙ БИ СИ БАНК БЪЛГАРИЯ ЕАД
#  2207136  ГЕРБ, ОБЕДИНЕНИ ПАТРИОТИ  КЕЙ БИ СИ БАНК БЪЛГАРИЯ ЕАД
#  2209880  ГЕРБ, ОБЕДИНЕНИ ПАТРИОТИ  КЕЙ БИ СИ БАНК БЪЛГАРИЯ ЕАД
#  2212311  ГЕРБ, ОБЕДИНЕНИ ПАТРИОТИ  КЕЙ БИ СИ БАНК БЪЛГАРИЯ ЕАД
#  ...                           ...                          ...
#  3542892          ПП, БСП, ИТН, ДБ  КЕЙ БИ СИ БАНК БЪЛГАРИЯ ЕАД
#  3564694                       NaN  КЕЙ БИ СИ БАНК БЪЛГАРИЯ ЕАД
#  3566684          ПП, БСП, ИТН, ДБ  КЕЙ БИ СИ БАНК БЪЛГАРИЯ ЕАД
#  3577210          ПП, БСП, ИТН, ДБ  КЕЙ БИ СИ БАНК БЪЛГАРИЯ ЕАД
#  3580839          ПП, БСП, ИТН, ДБ  КЕЙ БИ СИ БАНК БЪЛГАРИЯ ЕАД
#
#  [265 rows x 21 columns],
#  array(['96C701EEC49C76B8805B8A39A27BA659973FFC7C58569212959ED648EED4EA3B',
#         '68772E1ADEC12A9CCB1E274421C0144A1AC5EBAECC8756DC56D82575CA315DD5',
#         'FC3823D7B3DD8382E549F6D42AEE268E8EAA05097C7F3FA0C1915352CCAF515B',
#         '47A5FFFDA2487319A8CF7034CFE930B3388D67F2E562CC706A4936755EB2394E',
#         '913AC1EE75AF689409B2EA7F82563ECE7B712DF4EFF2C67297978B912E10FD50',
#         '770740ADE87E80EC003D6574ACF614DDE567F0F399041357B92D7037242BBB5F'],
#        dtype=object),
#  array(['ФИЗИЧЕСКО ЛИЦЕ', 'ОБЩИНА РАКИТОВО', '6309 ОБЩИНА РАКИТОВО',
#         'OBSHTINA RAKITOVO DARZHAVNI I OBSHT', 'ОБЩ.РАКИТОВО'],
#        dtype=object),
#                                                                       sum  \
#  primary_organization                               reg_year
#  МИНИСТЕРСТВО НА ТРУДА И СОЦИАЛНАТА ПОЛИТИКА        2017         80282.63
#  ЦБ - СУБСИДИИ ЗА ОБЩИНИ                            2017       2127523.99
#  МИНИСТЕРСКИ СЪВЕТ                                  2018         15000.00
#  МИНИСТЕРСТВО НА РЕГИОНАЛНОТО РАЗВИТ                2018         36480.00
#  МИНИСТЕРСТВО НА ТРУДА И СОЦИАЛНАТА ПОЛИТИКА        2018        352408.48
#  ЦБ - СУБСИДИИ ЗА ОБЩИНИ                            2018       8263079.08
#  МОСВ-ЧУЖДИ СРЕДСТВА                                2018        271519.20
#  ЦБ - СУБСИДИИ ЗА ОБЩИНИ                            2019       9466275.77
#  ПРЕДПРИЯТИЕ ЗА УПРАВЛЕНИЕ НА ДЕЙНОСТИТЕ ПО ОПАЗ... 2019        218799.88
#  МОСВ-ЧУЖДИ СРЕДСТВА                                2019         59880.00
#  МИНИСТЕРСТВО НА ТРУДА И СОЦИАЛНАТА ПОЛИТИКА        2019        312077.32
#  МОСВ-ЧУЖДИ СРЕДСТВА                                2020         77880.00
#  ПРЕДПРИЯТИЕ ЗА УПРАВЛЕНИЕ НА ДЕЙНОСТИТЕ ПО ОПАЗ... 2020       1023830.78
#  МИНИСТЕРСТВО НА ТРУДА И СОЦИАЛНАТА ПОЛИТИКА        2020        451292.82
#  ЦБ - СУБСИДИИ ЗА ОБЩИНИ                            2020      10804822.25
#                                                     2021      12725069.90
#  МОСВ-ЧУЖДИ СРЕДСТВА                                2021        311159.29
#  МИНИСТЕРСТВО НА ТРУДА И СОЦИАЛНАТА ПОЛИТИКА        2021        865719.09
#  ПРЕДПРИЯТИЕ ЗА УПРАВЛЕНИЕ НА ДЕЙНОСТИТЕ ПО ОПАЗ... 2021        694294.15
#  МИНИСТЕРСТВО НА РЕГИОНАЛНОТО РАЗВИТ                2021         36480.00
#  МИНИСТЕРСТВО НА ТРУДА И СОЦИАЛНАТА ПОЛИТИКА        2022        486339.75
#  ЦБ - СУБСИДИИ ЗА ОБЩИНИ                            2022       3890000.00
#
#                                                               count
#  primary_organization                               reg_year
#  МИНИСТЕРСТВО НА ТРУДА И СОЦИАЛНАТА ПОЛИТИКА        2017          4
#  ЦБ - СУБСИДИИ ЗА ОБЩИНИ                            2017         13
#  МИНИСТЕРСКИ СЪВЕТ                                  2018          2
#  МИНИСТЕРСТВО НА РЕГИОНАЛНОТО РАЗВИТ                2018          1
#  МИНИСТЕРСТВО НА ТРУДА И СОЦИАЛНАТА ПОЛИТИКА        2018         22
#  ЦБ - СУБСИДИИ ЗА ОБЩИНИ                            2018         33
#  МОСВ-ЧУЖДИ СРЕДСТВА                                2018          2
#  ЦБ - СУБСИДИИ ЗА ОБЩИНИ                            2019         26
#  ПРЕДПРИЯТИЕ ЗА УПРАВЛЕНИЕ НА ДЕЙНОСТИТЕ ПО ОПАЗ... 2019          1
#  МОСВ-ЧУЖДИ СРЕДСТВА                                2019          1
#  МИНИСТЕРСТВО НА ТРУДА И СОЦИАЛНАТА ПОЛИТИКА        2019         21
#  МОСВ-ЧУЖДИ СРЕДСТВА                                2020          1
#  ПРЕДПРИЯТИЕ ЗА УПРАВЛЕНИЕ НА ДЕЙНОСТИТЕ ПО ОПАЗ... 2020          2
#  МИНИСТЕРСТВО НА ТРУДА И СОЦИАЛНАТА ПОЛИТИКА        2020         17
#  ЦБ - СУБСИДИИ ЗА ОБЩИНИ                            2020         29
#                                                     2021         34
#  МОСВ-ЧУЖДИ СРЕДСТВА                                2021          4
#  МИНИСТЕРСТВО НА ТРУДА И СОЦИАЛНАТА ПОЛИТИКА        2021         29
#  ПРЕДПРИЯТИЕ ЗА УПРАВЛЕНИЕ НА ДЕЙНОСТИТЕ ПО ОПАЗ... 2021          3
#  МИНИСТЕРСТВО НА РЕГИОНАЛНОТО РАЗВИТ                2021          1
#  МИНИСТЕРСТВО НА ТРУДА И СОЦИАЛНАТА ПОЛИТИКА        2022         12
#  ЦБ - СУБСИДИИ ЗА ОБЩИНИ                            2022          7  ]

# %% [markdown]
# ## Time series per organization

# %%
# Get a table linking primary_org_number to one name for the organization
# The names are usually sufficiently telling, keeping the last name only
orgs_and_codes = data.loc[:, ['primary_organization', 'primary_org_code']].drop_duplicates(subset = ['primary_org_code'], keep = "last")

organizations_monthly = (data.
                         groupby('primary_org_code').
                         resample('MS', on = 'settlement_date')["amount"].
                         sum().
                         reset_index(drop = False).
                         merge(orgs_and_codes,
                               how = 'left',
                               on = 'primary_org_code'
                               )
                         )

# %%
organizations_monthly.sample(30)
# Out:
#        primary_org_code settlement_date       amount  \
# 5326                 41      2022-01-01    193302.03
# 3901                 25      2020-09-01   3432648.62
# 13998               868      2013-05-01    125175.63
# 6277                 46      2018-01-01     67991.84
# 2470                 18      2008-06-01   4009691.02
# 5874                 44      2018-03-01     28211.42
# 5894                 44      2019-11-01     84750.62
# 757                   4      2018-07-01      5202.60
# 4415                 33      2020-12-01    102280.28
# 6122                 45      2021-11-01    706426.94
# 6781                 53      2022-01-01   3208442.04
# 5360                 42      2008-03-01     20293.45
# 11479               816      2022-07-01     10000.00
# 13737               859      2017-04-01    414953.12
# 14886               890      2016-10-01   1750064.84
# 15842               989      2021-11-01   2167374.45
# 5313                 41      2020-12-01   2522978.18
# 11737               818      2010-03-01    214562.61
# 6044                 45      2015-05-01     49794.13
# 1573                 11      2018-09-01  10731379.53
# 5732                 43      2022-06-01   8221735.39
# 14903               890      2018-03-01   2736307.19
# 7701                 63      2015-12-01    259962.37
# 917                   5      2014-12-01    115852.11
# 5012                 40      2012-11-01     31995.00
# 8985                124      2021-02-01   4729503.72
# 102                   1      2014-07-01   1572769.16
# 13705               859      2014-08-01    345290.36
# 919                   5      2015-02-01     60864.38
# 11347               816      2011-07-01    952260.56
#
#                                  primary_organization
# 5326                НАЦИОНАЛЕН СТАТИСТИЧЕСКИ ИНСТИТУТ
# 3901                МИНИСТЕРСТВО НА МЛАДЕЖТА И СПОРТА
# 13998        ВИСШЕ ТРАНСПОРТНО УЧИЛИЩЕ "Т. КАБЛЕШКОВ"
# 6277                     АГЕНЦИЯ ЗА ЯДРЕНО РЕГУЛИРАНЕ
# 2470                        МИНИСТЕРСТВО НА КУЛТУРАТА
# 5874                        СЪВЕТ ЗА ЕЛЕКТРОННИ МЕДИИ
# 5894                        СЪВЕТ ЗА ЕЛЕКТРОННИ МЕДИИ
# 757                                КОНСТИТУЦИОНЕН СЪД
# 4415               КОМИСИЯ ЗА ЗАЩИТА ОТ ДИСКРИМИНАЦИЯ
# 6122              КОМИСИЯ ЗА ЕНЕРГ.И ВОДНО РЕГУЛИРАНЕ
# 6781     ДА "ДЪРЖАВЕН РЕЗЕРВ И ВОЕННОВРЕМЕННИ ЗАПАСИ"
# 5360               КОМИСИЯ ЗА ЗАЩИТА НА КОНКУРЕНЦИЯТА
# 11479             УНИВЕРСИТЕТ ПО АРХИТЕКТУРА, СТРОИТЕ
# 13737         НАЦИОНАЛНА СПОРТНА АКАДЕМИЯ "В. ЛЕВСКИ"
# 14886                   БЪЛГАРСКА АКАДЕМИЯ НА НАУКИТЕ
# 15842                НФ - ДРУГИ МЕЖДУНАРОДНИ ПРОГРАМИ
# 5313                НАЦИОНАЛЕН СТАТИСТИЧЕСКИ ИНСТИТУТ
# 11737                      ЛЕСОТЕХНИЧЕСКИ УНИВЕРСИТЕТ
# 6044              КОМИСИЯ ЗА ЕНЕРГ.И ВОДНО РЕГУЛИРАНЕ
# 1573                  МИНИСТЕРСТВО НА ВЪНШНИТЕ РАБОТИ
# 5732              КОМИСИЯ ЗА РЕГУЛИРАНЕ НА СЪОБЩЕНИЯТ
# 14903                   БЪЛГАРСКА АКАДЕМИЯ НА НАУКИТЕ
# 7701                     БЪЛГАРСКА ТЕЛЕГРАФНА АГЕНЦИЯ
# 917                                     СМЕТНА ПАЛАТА
# 5012                                        ОМБУДСМАН
# 8985   ФОНД "СИГУРНОСТ НА ЕЛЕКТРОЕНЕРГИЙНАТА СИСТЕМА"
# 102                                  НАРОДНО СЪБРАНИЕ
# 13705         НАЦИОНАЛНА СПОРТНА АКАДЕМИЯ "В. ЛЕВСКИ"
# 919                                     СМЕТНА ПАЛАТА
# 11347             УНИВЕРСИТЕТ ПО АРХИТЕКТУРА, СТРОИТЕ

# %%
(organizations_monthly.
 loc[lambda d:d['primary_organization'].str.contains("МИНИСТЕРСТВО")].
 pipe(plot_organization_timeseries, custom_title = "Payments over time - Ministries"))
# Out:
# alt.Chart(...)

# %% [markdown]
# #### What's going one with "МИНИСТЕРСТВО НА РЕГИОНАЛНОТО РАЗВИТ" and December spending!?

# %%
(data.
 loc[lambda d: (d["primary_org_code"] == 21) & (d["settlement_date"].dt.month == 12)].
 assign(
     settlement_month = lambda d: d["settlement_date"].dt.to_period('M')
 ).
 groupby(["client_receiver_name", "settlement_month"]).amount.sum().
 round().
 unstack().
 fillna(0).
 assign(
     overall = lambda d: d.sum(axis = 1)
 ).
 sort_values(by = 'overall', ascending = False).
 head(100).
 style.format("{:,.0f}")
 )
# Out:
# <style type="text/css">
# </style>
# <table id="T_791f3_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >settlement_month</th>
#       <th class="col_heading level0 col0" >2006-12</th>
#       <th class="col_heading level0 col1" >2007-12</th>
#       <th class="col_heading level0 col2" >2008-12</th>
#       <th class="col_heading level0 col3" >2009-12</th>
#       <th class="col_heading level0 col4" >2010-12</th>
#       <th class="col_heading level0 col5" >2011-12</th>
#       <th class="col_heading level0 col6" >2012-12</th>
#       <th class="col_heading level0 col7" >2013-12</th>
#       <th class="col_heading level0 col8" >2014-12</th>
#       <th class="col_heading level0 col9" >2015-12</th>
#       <th class="col_heading level0 col10" >2016-12</th>
#       <th class="col_heading level0 col11" >2017-12</th>
#       <th class="col_heading level0 col12" >2018-12</th>
#       <th class="col_heading level0 col13" >2019-12</th>
#       <th class="col_heading level0 col14" >2020-12</th>
#       <th class="col_heading level0 col15" >2021-12</th>
#       <th class="col_heading level0 col16" >2022-12</th>
#       <th class="col_heading level0 col17" >overall</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >client_receiver_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_791f3_level0_row0" class="row_heading level0 row0" >МРРБ</th>
#       <td id="T_791f3_row0_col0" class="data row0 col0" >10,271,424</td>
#       <td id="T_791f3_row0_col1" class="data row0 col1" >17,656,586</td>
#       <td id="T_791f3_row0_col2" class="data row0 col2" >11,011,317</td>
#       <td id="T_791f3_row0_col3" class="data row0 col3" >7,082,404</td>
#       <td id="T_791f3_row0_col4" class="data row0 col4" >5,763,497</td>
#       <td id="T_791f3_row0_col5" class="data row0 col5" >5,257,208</td>
#       <td id="T_791f3_row0_col6" class="data row0 col6" >4,566,228</td>
#       <td id="T_791f3_row0_col7" class="data row0 col7" >15,418</td>
#       <td id="T_791f3_row0_col8" class="data row0 col8" >1,437,172</td>
#       <td id="T_791f3_row0_col9" class="data row0 col9" >3,958,410</td>
#       <td id="T_791f3_row0_col10" class="data row0 col10" >1,005,896,698</td>
#       <td id="T_791f3_row0_col11" class="data row0 col11" >1,006,122,157</td>
#       <td id="T_791f3_row0_col12" class="data row0 col12" >1,356,276,058</td>
#       <td id="T_791f3_row0_col13" class="data row0 col13" >484,068,128</td>
#       <td id="T_791f3_row0_col14" class="data row0 col14" >3,788,480</td>
#       <td id="T_791f3_row0_col15" class="data row0 col15" >334,704</td>
#       <td id="T_791f3_row0_col16" class="data row0 col16" >0</td>
#       <td id="T_791f3_row0_col17" class="data row0 col17" >3,923,505,889</td>
#     </tr>
#     <tr>
#       <th id="T_791f3_level0_row1" class="row_heading level0 row1" >АВТОМАГИСТРАЛИ ЕАД</th>
#       <td id="T_791f3_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_791f3_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_791f3_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_791f3_row1_col3" class="data row1 col3" >1,899,154</td>
#       <td id="T_791f3_row1_col4" class="data row1 col4" >2,870,780</td>
#       <td id="T_791f3_row1_col5" class="data row1 col5" >2,862,632</td>
#       <td id="T_791f3_row1_col6" class="data row1 col6" >1,641,797</td>
#       <td id="T_791f3_row1_col7" class="data row1 col7" >3,514,913</td>
#       <td id="T_791f3_row1_col8" class="data row1 col8" >787,117</td>
#       <td id="T_791f3_row1_col9" class="data row1 col9" >17,237,712</td>
#       <td id="T_791f3_row1_col10" class="data row1 col10" >19,732,780</td>
#       <td id="T_791f3_row1_col11" class="data row1 col11" >7,876,504</td>
#       <td id="T_791f3_row1_col12" class="data row1 col12" >24,657,380</td>
#       <td id="T_791f3_row1_col13" class="data row1 col13" >199,681,846</td>
#       <td id="T_791f3_row1_col14" class="data row1 col14" >106,436,027</td>
#       <td id="T_791f3_row1_col15" class="data row1 col15" >29,262,718</td>
#       <td id="T_791f3_row1_col16" class="data row1 col16" >950,478</td>
#       <td id="T_791f3_row1_col17" class="data row1 col17" >419,411,838</td>
#     </tr>
#     <tr>
#       <th id="T_791f3_level0_row2" class="row_heading level0 row2" >ЕВРОПЕЙСКИ ПЪТИЩА АД</th>
#       <td id="T_791f3_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_791f3_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_791f3_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_791f3_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_791f3_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_791f3_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_791f3_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_791f3_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_791f3_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_791f3_row2_col9" class="data row2 col9" >0</td>
#       <td id="T_791f3_row2_col10" class="data row2 col10" >0</td>
#       <td id="T_791f3_row2_col11" class="data row2 col11" >0</td>
#       <td id="T_791f3_row2_col12" class="data row2 col12" >0</td>
#       <td id="T_791f3_row2_col13" class="data row2 col13" >46,609,189</td>
#       <td id="T_791f3_row2_col14" class="data row2 col14" >92,490,587</td>
#       <td id="T_791f3_row2_col15" class="data row2 col15" >298,465</td>
#       <td id="T_791f3_row2_col16" class="data row2 col16" >0</td>
#       <td id="T_791f3_row2_col17" class="data row2 col17" >139,398,241</td>
#     </tr>
#     <tr>
#       <th id="T_791f3_level0_row3" class="row_heading level0 row3" >АПИ</th>
#       <td id="T_791f3_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_791f3_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_791f3_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_791f3_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_791f3_row3_col4" class="data row3 col4" >34,170,504</td>
#       <td id="T_791f3_row3_col5" class="data row3 col5" >10,751,594</td>
#       <td id="T_791f3_row3_col6" class="data row3 col6" >1,470,487</td>
#       <td id="T_791f3_row3_col7" class="data row3 col7" >5,624,589</td>
#       <td id="T_791f3_row3_col8" class="data row3 col8" >14,602,089</td>
#       <td id="T_791f3_row3_col9" class="data row3 col9" >100,021</td>
#       <td id="T_791f3_row3_col10" class="data row3 col10" >25,061,195</td>
#       <td id="T_791f3_row3_col11" class="data row3 col11" >9,828,497</td>
#       <td id="T_791f3_row3_col12" class="data row3 col12" >9,492,716</td>
#       <td id="T_791f3_row3_col13" class="data row3 col13" >114,994</td>
#       <td id="T_791f3_row3_col14" class="data row3 col14" >49,197</td>
#       <td id="T_791f3_row3_col15" class="data row3 col15" >16,001,037</td>
#       <td id="T_791f3_row3_col16" class="data row3 col16" >11,586,676</td>
#       <td id="T_791f3_row3_col17" class="data row3 col17" >138,853,596</td>
#     </tr>
#     <tr>
#       <th id="T_791f3_level0_row4" class="row_heading level0 row4" >ПЪТИНЖЕНЕРИНГСТРОЙ Т ЕАД</th>
#       <td id="T_791f3_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_791f3_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_791f3_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_791f3_row4_col3" class="data row4 col3" >363,030</td>
#       <td id="T_791f3_row4_col4" class="data row4 col4" >11,534,389</td>

# %%
(data.
 loc[lambda d: (d["primary_org_code"] == 21) & (d["settlement_date"].dt.month == 12) & (d["client_receiver_name"] == "МРРБ")].
 assign(
     settlement_month = lambda d: d["settlement_date"].dt.to_period('M')
 ).
 groupby(['reason1', 'reason2', 'settlement_date']).amount.sum().
 sort_values(ascending = False).
 astype(np.int64).
 reset_index().
 head(100).
 style.format(thousands=",")
 )
# Out:
# <style type="text/css">
# </style>
# <table id="T_4fc90_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >reason1</th>
#       <th class="col_heading level0 col1" >reason2</th>
#       <th class="col_heading level0 col2" >settlement_date</th>
#       <th class="col_heading level0 col3" >amount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4fc90_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4fc90_row0_col0" class="data row0 col0" >ПОСТАНОВЛЕНИЕ 339/02.12.16</td>
#       <td id="T_4fc90_row0_col1" class="data row0 col1" >1216 12169339       021216</td>
#       <td id="T_4fc90_row0_col2" class="data row0 col2" >2016-12-22 00:00:00</td>
#       <td id="T_4fc90_row0_col3" class="data row0 col3" >1,000,000,000</td>
#     </tr>
#     <tr>
#       <th id="T_4fc90_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4fc90_row1_col0" class="data row1 col0" >ПОСТАНОВЛЕНИЕ 226/201217</td>
#       <td id="T_4fc90_row1_col1" class="data row1 col1" >1217 12179226       201217</td>
#       <td id="T_4fc90_row1_col2" class="data row1 col2" >2017-12-28 00:00:00</td>
#       <td id="T_4fc90_row1_col3" class="data row1 col3" >1,000,000,000</td>
#     </tr>
#     <tr>
#       <th id="T_4fc90_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4fc90_row2_col0" class="data row2 col0" >РД33 16/2019  АМ ХЕМУС</td>
#       <td id="T_4fc90_row2_col1" class="data row2 col1" >1219 12199ПМС 336   131219</td>
#       <td id="T_4fc90_row2_col2" class="data row2 col2" >2019-12-19 00:00:00</td>
#       <td id="T_4fc90_row2_col3" class="data row2 col3" >483,000,000</td>
#     </tr>
#     <tr>
#       <th id="T_4fc90_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4fc90_row3_col0" class="data row3 col0" >ПМС 298/7.12.2007</td>
#       <td id="T_4fc90_row3_col1" class="data row3 col1" >ПМС 319/18.12.2007 КЮСТ.ВОДА ЕООД</td>
#       <td id="T_4fc90_row3_col2" class="data row3 col2" >2007-12-27 00:00:00</td>
#       <td id="T_4fc90_row3_col3" class="data row3 col3" >9,000,000</td>
#     </tr>
#     <tr>
#       <th id="T_4fc90_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4fc90_row4_col0" class="data row4 col0" >ЗАХРАНВАНЕ НА ВАЛУТНА СМЕТКА СЪГЛ</td>
#       <td id="T_4fc90_row4_col1" class="data row4 col1" >П МО ИЗХ Н 99 00 4 871 031210</td>
#       <td id="T_4fc90_row4_col2" class="data row4 col2" >2010-12-13 00:00:00</td>
#       <td id="T_4fc90_row4_col3" class="data row4 col3" >3,684,783</td>
#     </tr>
#     <tr>
#       <th id="T_4fc90_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4fc90_row5_col0" class="data row5 col0" >ЗАХР.ВАЛ.С КА С ИЗХ.99 00 5 65/17.</td>
#       <td id="T_4fc90_row5_col1" class="data row5 col1" >12.20</td>
#       <td id="T_4fc90_row5_col2" class="data row5 col2" >2020-12-18 00:00:00</td>
#       <td id="T_4fc90_row5_col3" class="data row5 col3" >3,094,562</td>
#     </tr>
#     <tr>
#       <th id="T_4fc90_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4fc90_row6_col0" class="data row6 col0" >ЗАХРАНВАНЕ ВАЛУТНА СМЕТКА ИЗХ.N.</td>
#       <td id="T_4fc90_row6_col1" class="data row6 col1" >99 00 5 18/10.04.2018Г.</td>
#       <td id="T_4fc90_row6_col2" class="data row6 col2" >2018-12-04 00:00:00</td>
#       <td id="T_4fc90_row6_col3" class="data row6 col3" >3,029,813</td>
#     </tr>
#     <tr>
#       <th id="T_4fc90_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4fc90_row7_col0" class="data row7 col0" >ЗАХР.ВАЛ.С/КА ИЗХ.99 00 5 126/</td>
#       <td id="T_4fc90_row7_col1" class="data row7 col1" >12.12.16</td>
#       <td id="T_4fc90_row7_col2" class="data row7 col2" >2016-12-13 00:00:00</td>
#       <td id="T_4fc90_row7_col3" class="data row7 col3" >2,762,782</td>
#     </tr>
#     <tr>
#       <th id="T_4fc90_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4fc90_row8_col0" class="data row8 col0" >ЗАХРАНВАНЕ ВАЛ СМЕТКА ИЗХ 99 00 4</td>
#       <td id="T_4fc90_row8_col1" class="data row8 col1" >463/12.12.2012</td>
#       <td id="T_4fc90_row8_col2" class="data row8 col2" >2012-12-14 00:00:00</td>
#       <td id="T_4fc90_row8_col3" class="data row8 col3" >2,762,782</td>
#     </tr>
#     <tr>
#       <th id="T_4fc90_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4fc90_row9_col0" class="data row9 col0" >ЗАХРАНВАНЕ ВАЛ СМЕТКА ПО ПИСМО ИЗХ</td>
#       <td id="T_4fc90_row9_col1" class="data row9 col1" >99 00 4 773/28.11.11</td>
#       <td id="T_4fc90_row9_col2" class="data row9 col2" >2011-12-13 00:00:00</td>
#       <td id="T_4fc90_row9_col3" class="data row9 col3" >2,762,782</td>
#     </tr>
#     <tr>
#       <th id="T_4fc90_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4fc90_row10_col0" class="data row10 col0" >ЗАХРАНВАНЕ ВАЛУТНА СМЕТКА ИЗХ НОМ</td>
#       <td id="T_4fc90_row10_col1" class="data row10 col1" >99 00 5 109/09.12.2015</td>
#       <td id="T_4fc90_row10_col2" class="data row10 col2" >2015-12-14 00:00:00</td>
#       <td id="T_4fc90_row10_col3" class="data row10 col3" >2,762,782</td>
#     </tr>
#     <tr>
#       <th id="T_4fc90_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4fc90_row11_col0" class="data row11 col0" >ЗАХР.ВАЛ.С/КА ИЗХ. 99 00 5 137/</td>
#       <td id="T_4fc90_row11_col1" class="data row11 col1" >19.12.2016</td>
#       <td id="T_4fc90_row11_col2" class="data row11 col2" >2016-12-20 00:00:00</td>
#       <td id="T_4fc90_row11_col3" class="data row11 col3" >2,073,179</td>
#     </tr>
#     <tr>
#       <th id="T_4fc90_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4fc90_row12_col0" class="data row12 col0" >ЗАХРАНВАНЕ НА ВАЛУТНА СМЕТКА СЪГЛ.</td>
#       <td id="T_4fc90_row12_col1" class="data row12 col1" >ПИСМО ИЗХН.99 00 5 244 19.12.08</td>
#       <td id="T_4fc90_row12_col2" class="data row12 col2" >2008-12-20 00:00:00</td>
#       <td id="T_4fc90_row12_col3" class="data row12 col3" >1,893,567</td>
#     </tr>
#     <tr>
#       <th id="T_4fc90_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4fc90_row13_col0" class="data row13 col0" >ЗАХРАНВАНЕ ВАЛ СМЕТКА ПО ПИСМО</td>
#       <td id="T_4fc90_row13_col1" class="data row13 col1" >ИЗХ Н 99 00 5 172/10.12.09</td>
#       <td id="T_4fc90_row13_col2" class="data row13 col2" >2009-12-16 00:00:00</td>
#       <td id="T_4fc90_row13_col3" class="data row13 col3" >1,842,391</td>
#     </tr>
#     <tr>
#       <th id="T_4fc90_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4fc90_row14_col0" class="data row14 col0" >ЗАХРАНВАНЕ НА ВАЛУТНА СМЕТКА СЪГЛ</td>
#       <td id="T_4fc90_row14_col1" class="data row14 col1" >П МО ИЗХ Н 99 00 4 872 031210</td>
#       <td id="T_4fc90_row14_col2" class="data row14 col2" >2010-12-13 00:00:00</td>
#       <td id="T_4fc90_row14_col3" class="data row14 col3" >1,667,739</td>
#     </tr>
#     <tr>
#       <th id="T_4fc90_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4fc90_row15_col0" class="data row15 col0" >ЗАХРАНВАНЕ НА ВАЛУТНА СМЕТКА СЪГЛ.</td>
#       <td id="T_4fc90_row15_col1" class="data row15 col1" >П МО ВХ.Н.0408 0225 12.08.08Г</td>
#       <td id="T_4fc90_row15_col2" class="data row15 col2" >2008-12-08 00:00:00</td>
#       <td id="T_4fc90_row15_col3" class="data row15 col3" >1,597,684</td>
#     </tr>
#     <tr>
#       <th id="T_4fc90_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4fc90_row16_col0" class="data row16 col0" >АКРЕДИТИВ РОДОПАСТРОЙ ООД</td>
#       <td id="T_4fc90_row16_col1" class="data row16 col1" >ГР.МОМЧИЛГРАД</td>
#       <td id="T_4fc90_row16_col2" class="data row16 col2" >2007-12-28 00:00:00</td>
#       <td id="T_4fc90_row16_col3" class="data row16 col3" >1,577,491</td>
#     </tr>
#     <tr>
#       <th id="T_4fc90_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4fc90_row17_col0" class="data row17 col0" >ЗАХРАНВАНЕ НА СМЕТКА ПО ПИСМО</td>
#       <td id="T_4fc90_row17_col1" class="data row17 col1" >ИЗХ Н 99 00 5 177/151209</td>
#       <td id

# %%
(data.
 loc[lambda d: (d["client_receiver_name"].isin(["АВТОМАГИСТРАЛИ ЕАД", "ЕВРОПЕЙСКИ ПЪТИЩА АД", "ПЪТИНЖЕНЕРИНГСТРОЙ Т ЕАД", "ГБС ИНФРАСТРУКТ. С ВО АД", "ГБС ИНФР.С ВО АД"]))].
 groupby("primary_organization").amount.sum().reset_index().style.format(thousands=",")
 )
# Out:
# <style type="text/css">
# </style>
# <table id="T_e4e34_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >primary_organization</th>
#       <th class="col_heading level0 col1" >amount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4e34_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e4e34_row0_col0" class="data row0 col0" >ВИСШ СЪДЕБЕН СЪВЕТ</td>
#       <td id="T_e4e34_row0_col1" class="data row0 col1" >14,769.250000</td>
#     </tr>
#     <tr>
#       <th id="T_e4e34_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e4e34_row1_col0" class="data row1 col0" >МИНИСТЕРСКИ СЪВЕТ</td>
#       <td id="T_e4e34_row1_col1" class="data row1 col1" >3,076,501.490000</td>
#     </tr>
#     <tr>
#       <th id="T_e4e34_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e4e34_row2_col0" class="data row2 col0" >МИНИСТЕРСТВО НА ЕНЕРГЕТИКАТА</td>
#       <td id="T_e4e34_row2_col1" class="data row2 col1" >13,850.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e4e34_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e4e34_row3_col0" class="data row3 col0" >МИНИСТЕРСТВО НА РЕГИОНАЛНОТО РАЗВИТ</td>
#       <td id="T_e4e34_row3_col1" class="data row3 col1" >2,154,564,937.450000</td>
#     </tr>
#     <tr>
#       <th id="T_e4e34_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e4e34_row4_col0" class="data row4 col0" >МИНИСТЕРСТВО НА ТРУДА И СОЦИАЛНАТА ПОЛИТИКА</td>
#       <td id="T_e4e34_row4_col1" class="data row4 col1" >73,919.370000</td>
#     </tr>
#     <tr>
#       <th id="T_e4e34_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e4e34_row5_col0" class="data row5 col0" >МИНИСТЕРСТВО НА ФИНАНСИТЕ</td>
#       <td id="T_e4e34_row5_col1" class="data row5 col1" >10,349,756.680000</td>
#     </tr>
#     <tr>
#       <th id="T_e4e34_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e4e34_row6_col0" class="data row6 col0" >НА ПЪТНА ИНФРАСТРУКТУРА</td>
#       <td id="T_e4e34_row6_col1" class="data row6 col1" >14,004,880.790000</td>
#     </tr>
#     <tr>
#       <th id="T_e4e34_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e4e34_row7_col0" class="data row7 col0" >НАЦИОНАЛЕН ФОНД-КОХЕЗИОНЕН И СТРУКТУРНИ ФОНДОВЕ-2014-2020</td>
#       <td id="T_e4e34_row7_col1" class="data row7 col1" >21,033,290.400000</td>
#     </tr>
#     <tr>
#       <th id="T_e4e34_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e4e34_row8_col0" class="data row8 col0" >НФ - ЕСФ</td>
#       <td id="T_e4e34_row8_col1" class="data row8 col1" >651,882.470000</td>
#     </tr>
#     <tr>
#       <th id="T_e4e34_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e4e34_row9_col0" class="data row9 col0" >НФ - ЕФРР</td>
#       <td id="T_e4e34_row9_col1" class="data row9 col1" >831,347.160000</td>
#     </tr>
#     <tr>
#       <th id="T_e4e34_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e4e34_row10_col0" class="data row10 col0" >ЦБ - СУБСИДИИ ЗА ОБЩИНИ</td>
#       <td id="T_e4e34_row10_col1" class="data row10 col1" >1,332,303.120000</td>
#     </tr>
#     <tr>
#       <th id="T_e4e34_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e4e34_row11_col0" class="data row11 col0" >ЦЕНТРАЛЕН БЮДЖЕТ - БЕЗЛИХВЕНИ ЗАЕМИ</td>
#       <td id="T_e4e34_row11_col1" class="data row11 col1" >3,524,437.670000</td>
#     </tr>
#   </tbody>
# </table>

# %%
(data.
 loc[lambda d: (d["primary_org_code"] == 21) & (d["settlement_date"].dt.month == 5)].
 assign(
     settlement_month = lambda d: d["settlement_date"].dt.to_period('M')
 ).
 groupby(["client_receiver_name", "settlement_month"]).amount.sum().
 round().
 unstack().
 fillna(0).
 assign(
     overall = lambda d: d.sum(axis = 1)
 ).
 sort_values(by = 'overall', ascending = False).
 head(100).
 style.format("{:,.0f}")
 )
# Out:
# <style type="text/css">
# </style>
# <table id="T_435ce_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >settlement_month</th>
#       <th class="col_heading level0 col0" >2006-05</th>
#       <th class="col_heading level0 col1" >2007-05</th>
#       <th class="col_heading level0 col2" >2008-05</th>
#       <th class="col_heading level0 col3" >2009-05</th>
#       <th class="col_heading level0 col4" >2010-05</th>
#       <th class="col_heading level0 col5" >2011-05</th>
#       <th class="col_heading level0 col6" >2012-05</th>
#       <th class="col_heading level0 col7" >2013-05</th>
#       <th class="col_heading level0 col8" >2014-05</th>
#       <th class="col_heading level0 col9" >2015-05</th>
#       <th class="col_heading level0 col10" >2016-05</th>
#       <th class="col_heading level0 col11" >2017-05</th>
#       <th class="col_heading level0 col12" >2018-05</th>
#       <th class="col_heading level0 col13" >2019-05</th>
#       <th class="col_heading level0 col14" >2020-05</th>
#       <th class="col_heading level0 col15" >2021-05</th>
#       <th class="col_heading level0 col16" >2022-05</th>
#       <th class="col_heading level0 col17" >overall</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >client_receiver_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_435ce_level0_row0" class="row_heading level0 row0" >МРРБ</th>
#       <td id="T_435ce_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_435ce_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_435ce_row0_col2" class="data row0 col2" >1,157,075</td>
#       <td id="T_435ce_row0_col3" class="data row0 col3" >1,380,094</td>
#       <td id="T_435ce_row0_col4" class="data row0 col4" >1,861,184</td>
#       <td id="T_435ce_row0_col5" class="data row0 col5" >249,332</td>
#       <td id="T_435ce_row0_col6" class="data row0 col6" >4,436,705</td>
#       <td id="T_435ce_row0_col7" class="data row0 col7" >736,553</td>
#       <td id="T_435ce_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_435ce_row0_col9" class="data row0 col9" >391,817</td>
#       <td id="T_435ce_row0_col10" class="data row0 col10" >843,282</td>
#       <td id="T_435ce_row0_col11" class="data row0 col11" >181,035</td>
#       <td id="T_435ce_row0_col12" class="data row0 col12" >164,140</td>
#       <td id="T_435ce_row0_col13" class="data row0 col13" >140,527</td>
#       <td id="T_435ce_row0_col14" class="data row0 col14" >1,000,323,742</td>
#       <td id="T_435ce_row0_col15" class="data row0 col15" >134,091</td>
#       <td id="T_435ce_row0_col16" class="data row0 col16" >351,519</td>
#       <td id="T_435ce_row0_col17" class="data row0 col17" >1,012,351,096</td>
#     </tr>
#     <tr>
#       <th id="T_435ce_level0_row1" class="row_heading level0 row1" >БЪЛГАРСКИ ВИК ХОЛДИНГ ЕАД</th>
#       <td id="T_435ce_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_435ce_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_435ce_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_435ce_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_435ce_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_435ce_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_435ce_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_435ce_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_435ce_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_435ce_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_435ce_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_435ce_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_435ce_row1_col12" class="data row1 col12" >0</td>
#       <td id="T_435ce_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_435ce_row1_col14" class="data row1 col14" >1,000,000,000</td>
#       <td id="T_435ce_row1_col15" class="data row1 col15" >0</td>
#       <td id="T_435ce_row1_col16" class="data row1 col16" >0</td>
#       <td id="T_435ce_row1_col17" class="data row1 col17" >1,000,000,000</td>
#     </tr>
#     <tr>
#       <th id="T_435ce_level0_row2" class="row_heading level0 row2" >АВТОМАГИСТРАЛИ ЕАД</th>
#       <td id="T_435ce_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_435ce_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_435ce_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_435ce_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_435ce_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_435ce_row2_col5" class="data row2 col5" >1,725,037</td>
#       <td id="T_435ce_row2_col6" class="data row2 col6" >2,462,687</td>
#       <td id="T_435ce_row2_col7" class="data row2 col7" >676,482</td>
#       <td id="T_435ce_row2_col8" class="data row2 col8" >828,178</td>
#       <td id="T_435ce_row2_col9" class="data row2 col9" >1,883,652</td>
#       <td id="T_435ce_row2_col10" class="data row2 col10" >2,055,996</td>
#       <td id="T_435ce_row2_col11" class="data row2 col11" >8,099,039</td>
#       <td id="T_435ce_row2_col12" class="data row2 col12" >2,224,715</td>
#       <td id="T_435ce_row2_col13" class="data row2 col13" >3,282,532</td>
#       <td id="T_435ce_row2_col14" class="data row2 col14" >3,495,092</td>
#       <td id="T_435ce_row2_col15" class="data row2 col15" >16,992</td>
#       <td id="T_435ce_row2_col16" class="data row2 col16" >89,396,864</td>
#       <td id="T_435ce_row2_col17" class="data row2 col17" >116,147,266</td>
#     </tr>
#     <tr>
#       <th id="T_435ce_level0_row3" class="row_heading level0 row3" >КОНС. КАПШ ТРАФИК СОЛЮШЪНС</th>
#       <td id="T_435ce_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_435ce_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_435ce_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_435ce_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_435ce_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_435ce_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_435ce_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_435ce_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_435ce_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_435ce_row3_col9" class="data row3 col9" >0</td>
#       <td id="T_435ce_row3_col10" class="data row3 col10" >0</td>
#       <td id="T_435ce_row3_col11" class="data row3 col11" >0</td>
#       <td id="T_435ce_row3_col12" class="data row3 col12" >0</td>
#       <td id="T_435ce_row3_col13" class="data row3 col13" >89,998,200</td>
#       <td id="T_435ce_row3_col14" class="data row3 col14" >0</td>
#       <td id="T_435ce_row3_col15" class="data row3 col15" >0</td>
#       <td id="T_435ce_row3_col16" class="data row3 col16" >0</td>
#       <td id="T_435ce_row3_col17" class="data row3 col17" >89,998,200</td>
#     </tr>
#     <tr>
#       <th id="T_435ce_level0_row4" class="row_heading level0 row4" >АПИ</th>
#       <td id="T_435ce_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_435ce_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_435ce_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_435ce_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_435ce_row4_col4" class="data row4 col4" >1,472,388</td>
#       <td id="T_435ce_row4_col5" class="data row4 col5" >704,178</td>
#       <td id="T_435ce_row4_col6" class="data row4 col6" >112,881</td>
#       <td id="T_435ce_row4_col7"

# %%
(organizations_monthly.
 loc[lambda d:d['primary_organization'].str.contains("УНИВЕРСИТЕТ|УНСС|СУ КЛИМЕНТ ОХРИДСКИ|АКАДЕМИЯ")].
 pipe(plot_organization_timeseries))
# Out:
# alt.Chart(...)

# %%
organizations_monthly.sort_values(by='amount', ascending = False).head(1000).primary_organization.unique()
# Out:
# array(['НОИ - ДОО', 'МИНИСТЕРСТВО НА РЕГИОНАЛНОТО РАЗВИТ',
#        'МИНИСТЕРСТВО НА ЕНЕРГЕТИКАТА', 'МИНИСТЕРСТВО НА ЗЕМЕДЕЛИЕТО',
#        'ЦБ - СУБСИДИИ ЗА ОБЩИНИ',
#        'МИНИСТЕРСТВО НА ИКОНОМИКАТА И ИНДУСТРИЯТА',
#        'ДФ ЗЕМЕДЕЛИЕ-РАЗПЛАЩАТЕЛНА АГЕНЦИЯ', 'НЗОК',
#        'МИНИСТЕРСТВО НА ЗДРАВЕОПАЗВАНЕТО',
#        'ФОНД "СИГУРНОСТ НА ЕЛЕКТРОЕНЕРГИЙНАТА СИСТЕМА"', 'НФ - ЕФРР',
#        'МИНИСТЕРСТВО НА ТРАНСПОРТА',
#        'МИНИСТЕРСТВО НА ТРУДА И СОЦИАЛНАТА ПОЛИТИКА',
#        'ПРЕДПРИЯТИЕ ЗА УПРАВЛЕНИЕ НА ДЕЙНОСТИТЕ ПО ОПАЗВАНЕ НА ОКОЛНАТА СРЕДА',
#        'НАЦИОНАЛЕН ФОНД-КОХЕЗИОНЕН И СТРУКТУРНИ ФОНДОВЕ-2014-2020',
#        'МИНИСТЕРСТВО НА ДЪРЖАВНАТА ПОЛИТИКА', 'МИНИСТЕРСТВО НА ФИНАНСИТЕ',
#        'НФ-АВАНСОВО ФИНАНСИРАНЕ ЗА ПРОЕКТИ ПО КФ, ЕФРР, ЕСФ',
#        'НФ - КОХЕЗИОНЕН ФОНД', 'ЦЕНТРАЛЕН БЮДЖЕТ - БЕЗЛИХВЕНИ ЗАЕМИ',
#        'ДЪРЖАВЕН ФОНД ЗЕМЕДЕЛИЕ',
#        'ФОНД ЗА ПОКРИВАНЕ НА РАЗХОДИТЕ ЗА  ПРИВАТИЗАЦИЯ И СЛЕДПРИВАТИЗАЦИОНЕН КОНТРОЛ',
#        'МИНИСТЕРСТВО НА ОБРАЗОВАНИЕТО, МЛАДЕЖТА И НАУКАТА',
#        'НА ПЪТНА ИНФРАСТРУКТУРА',
#        'ДА "ДЪРЖАВЕН РЕЗЕРВ И ВОЕННОВРЕМЕННИ ЗАПАСИ"',
#        'МИНСТЕРСТВО НА ОКОЛНАТА СРЕДА И ВОД'], dtype=object)

# %% [markdown]
# ## Some work on vectorizing the transfer reasons

# %%
# !pip install whatlies[all]

# %%
# from sklearn.pipeline import make_pipeline
# from sklearn.decomposition import TruncatedSVD

# from whatlies.language import BytePairLanguage
# from whatlies.transformers import Umap

# %%
# lang_bp1 = BytePairLanguage("bg", vs=200000, dim=300)

# %%
# comments_combined = list(data.reason1.fillna(" ") + " " + data.reason2.fillna(" "))

# %%
# comments_vectorized = lang_bp1.fit_transform(comments_combined)

# %%
# km = MiniBatchKMeans(
#         n_clusters=k_means_clusters,
#         init="k-means++",
#         n_init=1,
#         init_size=1000,
#         batch_size=1000
#     )

# clust_pipe = make_pipeline(lang_bp1, km)

# %%
#clusters_reason1 = clust_pipe.fit_predict(list(data.reason1.fillna(" ")))
